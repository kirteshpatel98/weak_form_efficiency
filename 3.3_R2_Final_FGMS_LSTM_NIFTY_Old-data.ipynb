# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\agarw\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: kt-legacy in c:\users\agarw\anaconda3\lib\site-packages (from keras-tuner) (1.0.4)
# Requirement already satisfied: ipython in c:\users\agarw\anaconda3\lib\site-packages (from keras-tuner) (8.2.0)
# Requirement already satisfied: requests in c:\users\agarw\anaconda3\lib\site-packages (from keras-tuner) (2.27.1)
# Requirement already satisfied: tensorflow>=2.0 in c:\users\agarw\anaconda3\lib\site-packages (from keras-tuner) (2.11.0)
# Requirement already satisfied: packaging in c:\users\agarw\anaconda3\lib\site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.30.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.21.5)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (23.1.21)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (15.0.6.1)
# Requirement already satisfied: setuptools in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (61.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.19.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.42.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.2)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\agarw\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.33.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.3.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\agarw\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\agarw\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\agarw\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\agarw\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agarw\anaconda3\lib\site-packages (from requests->keras-tuner) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\agarw\anaconda3\lib\site-packages (from requests->keras-tuner) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agarw\anaconda3\lib\site-packages (from requests->keras-tuner) (2022.9.24)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.2.2)
# Requirement already satisfied: backcall in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: colorama in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.18.1)
# Requirement already satisfied: decorator in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (3.0.20)
# Requirement already satisfied: stack-data in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.1.2)
# Requirement already satisfied: traitlets>=5 in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (2.11.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\agarw\anaconda3\lib\site-packages (from jedi>=0.16->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\agarw\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\agarw\anaconda3\lib\site-packages (from packaging->keras-tuner) (3.0.4)
# Requirement already satisfied: pure-eval in c:\users\agarw\anaconda3\lib\site-packages (from stack-data->ipython->keras-tuner) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\agarw\anaconda3\lib\site-packages (from stack-data->ipython->keras-tuner) (2.0.5)
# Requirement already satisfied: executing in c:\users\agarw\anaconda3\lib\site-packages (from stack-data->ipython->keras-tuner) (0.8.3)

# %% [markdown]
# # LSTM Model_NIFTY FROM 2011 TO 2015

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller, acf, pacf
import yfinance as yf
import math
from sklearn.metrics import mean_squared_error
import pandas_datareader as pdr
import os
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Data Acquisition

# %%
df = yf.download('^NSEI',start="2011-01-31", end="2015-12-31",interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2015-12-23 00:00:00+05:30  7830.450195  7871.450195  7826.100098  7865.950195
# 2015-12-24 00:00:00+05:30  7888.750000  7888.750000  7835.500000  7861.049805
# 2015-12-28 00:00:00+05:30  7863.200195  7937.200195  7863.000000  7925.149902
# 2015-12-29 00:00:00+05:30  7929.200195  7942.149902  7902.750000  7928.950195
# 2015-12-30 00:00:00+05:30  7938.600098  7944.750000  7889.850098  7896.250000
#
#                              Adj Close  Volume
# Date
# 2015-12-23 00:00:00+05:30  7865.950195  117900
# 2015-12-24 00:00:00+05:30  7861.049805   93500
# 2015-12-28 00:00:00+05:30  7925.149902  122900
# 2015-12-29 00:00:00+05:30  7928.950195  113000
# 2015-12-30 00:00:00+05:30  7896.250000  106800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1195 entries, 2011-01-31 00:00:00+05:30 to 2015-12-30 00:00:00+05:30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1195 non-null   float64
#  1   High       1195 non-null   float64
#  2   Low        1195 non-null   float64
#  3   Close      1195 non-null   float64
#  4   Adj Close  1195 non-null   float64
#  5   Volume     1195 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 65.4 KB

# %%
df
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2011-01-31 00:00:00+05:30  5452.549805  5526.850098  5416.649902  5505.899902
# 2011-02-01 00:00:00+05:30  5537.299805  5539.149902  5402.000000  5417.200195
# 2011-02-02 00:00:00+05:30  5469.549805  5490.600098  5415.649902  5432.000000
# 2011-02-03 00:00:00+05:30  5430.450195  5532.649902  5418.000000  5526.750000
# 2011-02-04 00:00:00+05:30  5519.899902  5556.299805  5369.049805  5395.750000
# ...                                ...          ...          ...          ...
# 2015-12-23 00:00:00+05:30  7830.450195  7871.450195  7826.100098  7865.950195
# 2015-12-24 00:00:00+05:30  7888.750000  7888.750000  7835.500000  7861.049805
# 2015-12-28 00:00:00+05:30  7863.200195  7937.200195  7863.000000  7925.149902
# 2015-12-29 00:00:00+05:30  7929.200195  7942.149902  7902.750000  7928.950195
# 2015-12-30 00:00:00+05:30  7938.600098  7944.750000  7889.850098  7896.250000
#
#                              Adj Close  Volume
# Date
# 2011-01-31 00:00:00+05:30  5505.899902       0
# 2011-02-01 00:00:00+05:30  5417.200195       0
# 2011-02-02 00:00:00+05:30  5432.000000       0
# 2011-02-03 00:00:00+05:30  5526.750000       0
# 2011-02-04 00:00:00+05:30  5395.750000       0
# ...                                ...     ...
# 2015-12-23 00:00:00+05:30  7865.950195  117900
# 2015-12-24 00:00:00+05:30  7861.049805   93500
# 2015-12-28 00:00:00+05:30  7925.149902  122900
# 2015-12-29 00:00:00+05:30  7928.950195  113000
# 2015-12-30 00:00:00+05:30  7896.250000  106800
#
# [1195 rows x 6 columns]

# %% [markdown]
# # Data Preparation

# %%
df["Return"] = df["Adj Close"].pct_change()

# %%
df1 = df.drop(columns = ["Open","High","Low","Adj Close", "Volume"])

# %%
df1
# Out:
#                                  Close    Return
# Date
# 2011-01-31 00:00:00+05:30  5505.899902       NaN
# 2011-02-01 00:00:00+05:30  5417.200195 -0.016110
# 2011-02-02 00:00:00+05:30  5432.000000  0.002732
# 2011-02-03 00:00:00+05:30  5526.750000  0.017443
# 2011-02-04 00:00:00+05:30  5395.750000 -0.023703
# ...                                ...       ...
# 2015-12-23 00:00:00+05:30  7865.950195  0.010255
# 2015-12-24 00:00:00+05:30  7861.049805 -0.000623
# 2015-12-28 00:00:00+05:30  7925.149902  0.008154
# 2015-12-29 00:00:00+05:30  7928.950195  0.000480
# 2015-12-30 00:00:00+05:30  7896.250000 -0.004124
#
# [1195 rows x 2 columns]

# %%
df1["Log_Return"] = np.log(1+df1["Return"])

# %%
df1 = df1.dropna()

# %%
df2 = df1["Log_Return"]

# %%
plt.figure(figsize=(16,6))
plt.title('Log Return History')
plt.plot(df2)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Return USD ($)', fontsize=18)
plt.show()

# %%
# Create a histogram of stock data
plt.figure(figsize = (15,6))
plt.hist(df2, bins=30, alpha=0.5, color='blue')

# Add a vertical line for the mean
plt.axvline(df2.mean(), color='red', linestyle='dashed', linewidth=2)

# Add labels and title
plt.xlabel("Date")
plt.ylabel("Log_Return")
plt.title('Histogram of Stock Data')

# Show the plot
plt.show()

# %% [markdown]
# # Scaling Data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df3 = scaler.fit_transform(np.array(df2).reshape(-1, 1))

# %%
df3
# Out:
# array([[-1.54293528],
#        [ 0.2262947 ],
#        [ 1.58466965],
#        ...,
#        [ 0.72926803],
#        [ 0.01654803],
#        [-0.41361044]])

# %% [markdown]
# # Train Test Split

# %%
train_size = int(len(df3)*0.8)
test_size = len(df3)-train_size
train_size,test_size
# Out:
# (955, 239)

# %%
train_data,test_data = df3[0:train_size],df3[train_size:]

# %%
train_data.shape,test_data.shape
# Out:
# ((955, 1), (239, 1))

# %%
def creat_dataset(data, time_stamp):
    data_x, data_y = [], []
    for i in range(len(data)-time_stamp-1):
        a = data[i: i + time_stamp, 0]
        data_x.append(a)
        b = data[i+time_stamp,0]
        data_y.append(b)
    return data_x, data_y

# %%
x_train, y_train = creat_dataset(train_data,50)
x_test, y_test = creat_dataset(test_data,50)

# %%
x_train = np.asarray(x_train)
x_test = np.asarray(x_test)
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)
x_train,x_test
# Out:
# (array([[-1.54293528,  0.2262947 ,  1.58466965, ..., -0.72324304,
#          -0.93135155,  1.97804147],
#         [ 0.2262947 ,  1.58466965, -2.26549993, ..., -0.93135155,
#           1.97804147, -1.41019518],
#         [ 1.58466965, -2.26549993, -0.02384399, ...,  1.97804147,
#          -1.41019518, -1.56924872],
#         ...,
#         [-1.41177166,  0.35024188,  1.15949944, ...,  0.48900846,
#          -0.00611067,  0.36057132],
#         [ 0.35024188,  1.15949944,  0.54240094, ..., -0.00611067,
#           0.36057132,  1.23289598],
#         [ 1.15949944,  0.54240094,  0.77017158, ...,  0.36057132,
#           1.23289598, -0.21776932]]),
#  array([[ 1.48477009,  0.53531642,  0.40426707, ..., -0.58010836,
#          -0.7193187 , -0.24605742],
#         [ 0.53531642,  0.40426707, -0.29299833, ..., -0.7193187 ,
#          -0.24605742, -0.1149211 ],
#         [ 0.40426707, -0.29299833, -0.27404319, ..., -0.24605742,
#          -0.1149211 , -0.1609115 ],
#         ...,
#         [ 0.66167094, -0.55465501, -0.16455298, ...,  0.83895166,
#          -0.60554732,  0.9234664 ],
#         [-0.55465501, -0.16455298, -0.30154614, ..., -0.60554732,
#           0.9234664 , -0.08628793],
#         [-0.16455298, -0.30154614,  0.79185683, ...,  0.9234664 ,
#          -0.08628793,  0.72926803]]))

# %% [markdown]
# # Find the correlation in b/w daily Returns

# %%
import seaborn as sns 
from sklearn.preprocessing import Normalizer
normalizedx_train = Normalizer().fit_transform(x_train)

normalizedx_train = pd.DataFrame(normalizedx_train)
normalizedx_train
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.176568  0.025896  0.181344 -0.259256 -0.002729 -0.169576 -0.122421
# 1    0.025963  0.181811 -0.259924 -0.002736 -0.170013 -0.122736 -0.059904
# 2    0.178993 -0.255894 -0.002693 -0.167378 -0.120833 -0.058975  0.165207
# 3   -0.260050 -0.002737 -0.170096 -0.122796 -0.059933  0.167890  0.287155
# 4   -0.002775 -0.172438 -0.124486 -0.060758  0.170202  0.291109  0.046340
# ..        ...       ...       ...       ...       ...       ...       ...
# 899  0.051474 -0.053116 -0.279782  0.069410  0.229788  0.107492  0.152631
# 900 -0.053187 -0.280154  0.069502  0.230092  0.107635  0.152834 -0.015313
# 901 -0.279833  0.069423  0.229829  0.107512  0.152659 -0.015295  0.077277
# 902  0.070077  0.231995  0.108525  0.154098 -0.015439  0.078006  0.139899
# 903  0.232346  0.108689  0.154330 -0.015463  0.078124  0.140110  0.175393
#
#            7         8         9   ...        40        41        42  \
# 0   -0.059750  0.167377  0.286278  ...  0.091802  0.081455 -0.017320
# 1    0.167809  0.287016  0.045688  ...  0.081665 -0.017365  0.147053
# 2    0.282566  0.044980 -0.001836  ... -0.017096  0.144774 -0.000330
# 3    0.045711 -0.001865  0.122485  ...  0.147125 -0.000335 -0.036434
# 4   -0.001891  0.124171 -0.175863  ... -0.000340 -0.036936 -0.014428
# ..        ...       ...       ...  ...       ...       ...       ...
# 899 -0.015292  0.077263  0.138568  ... -0.015698 -0.350587 -0.092389
# 900  0.077366  0.138751  0.173692  ... -0.351052 -0.092512  0.290518
# 901  0.138593  0.173494  0.337455  ... -0.092406  0.290186  0.143132
# 902  0.175129  0.340636 -0.001263  ...  0.292921  0.144481  0.217184
# 903  0.341150 -0.001265  0.026097  ...  0.144699  0.217512 -0.134063
#
#            43        44        45        46        47        48        49
# 0    0.146675 -0.000334 -0.036323 -0.014188 -0.082765 -0.106581  0.226360
# 1   -0.000335 -0.036416 -0.014225 -0.082979 -0.106855  0.226943 -0.161794
# 2   -0.035852 -0.014004 -0.081692 -0.105199  0.223425 -0.159285 -0.177251
# 3   -0.014232 -0.083019 -0.106907  0.227054 -0.161872 -0.180130  0.018515
# 4   -0.084162 -0.108379  0.230180 -0.164101 -0.182610  0.018770  0.204388
# ..        ...       ...       ...       ...       ...       ...       ...
# 899  0.290133  0.143106  0.215118 -0.132587 -0.214466  0.054470  0.096911
# 900  0.143295  0.215403 -0.132763 -0.214751  0.054542  0.097039 -0.001213
# 901  0.215157 -0.132611 -0.214505  0.054480  0.096928 -0.001211  0.071470
# 902 -0.133861 -0.216527  0.054993  0.097842 -0.001223  0.072144  0.246681
# 903 -0.216854  0.055076  0.097990 -0.001224  0.072253  0.247053 -0.043638
#
# [904 rows x 50 columns]

# %% [markdown]
# # Pearson Correlation

# %%
# plot correlation heatmap
plt.figure(figsize = (40,20))
sns.heatmap(normalizedx_train.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1],1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1],1)

# %%
x_train.shape, x_test.shape
# Out:
# ((904, 50, 1), (188, 50, 1))

# %%
# Building Model

# %%
import keras_tuner
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM
from kerastuner import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
import tensorflow as tf
# Out:
# C:\Users\agarw\AppData\Local\Temp\ipykernel_2984\881150544.py:5: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner import RandomSearch

# %% [markdown]
# # Hyperparameter Tuning

# %%
my_learning_rate = .00001

# %%
def build_model(hp):
    model = Sequential()
    model.add(LSTM(hp.Int('input_unit',min_value=32,max_value=512,step=32),return_sequences=True, input_shape=(50,1)))
    for i in range(hp.Int('n_layers', 1, 4)):
        model.add(LSTM(hp.Int(f'lstm_{i}_units',min_value=32,max_value=512,step=32),return_sequences=True))
    model.add(LSTM(hp.Int('layer_2_neurons',min_value=32,max_value=512,step=32)))
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.5,step=0.1)))
    model.add(Dense(1, activation=hp.Choice('dense_activation',values=['relu', 'sigmoid'],default='relu')))
    model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.RMSprop(learning_rate=my_learning_rate),metrics = ['mse'])
    return model

# %%
tuner_search = RandomSearch(
    build_model,
    objective='mse',
    max_trials=1,
    directory='output',
    project_name='R1_Final_FGMS_LSTM_NIFTY_Old-data_model_2'
)

# %%
tuner_search.search(
        x=x_train,
        y=y_train,
        epochs=50,
        batch_size=10,
        validation_data=(x_test,y_test),
)
# Out:
# Trial 1 Complete [04h 47m 58s]
# mse: 0.9940307140350342
#
# Best mse So Far: 0.9940307140350342
# Total elapsed time: 04h 47m 58s
# INFO:tensorflow:Oracle triggered exit

# %%
model_1=tuner_search.get_best_models(num_models=1)[0]

# %%
# Fitting Model

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 192)           148992
#
#  lstm_1 (LSTM)               (None, 50, 480)           1292160
#
#  lstm_2 (LSTM)               (None, 50, 32)            65664
#
#  lstm_3 (LSTM)               (None, 288)               369792
#
#  dropout (Dropout)           (None, 288)               0
#
#  dense (Dense)               (None, 1)                 289
#
# =================================================================
# Total params: 1,876,897
# Trainable params: 1,876,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_1.fit(x=x_train,
        y=y_train,
        epochs=100,
        batch_size=10,
        validation_data=(x_test,x_test),
)
# Out:
# Epoch 1/49
# 91/91 [==============================] - 135s 861ms/step - loss: 0.9946 - mse: 0.9946 - val_loss: 0.9947 - val_mse: 0.9947
# Epoch 2/49
# 91/91 [==============================] - 47s 520ms/step - loss: 0.9939 - mse: 0.9939 - val_loss: 0.9949 - val_mse: 0.9949
# Epoch 3/49
# 91/91 [==============================] - 47s 519ms/step - loss: 0.9943 - mse: 0.9943 - val_loss: 0.9956 - val_mse: 0.9956
# Epoch 4/49
# 91/91 [==============================] - 48s 523ms/step - loss: 0.9942 - mse: 0.9942 - val_loss: 0.9957 - val_mse: 0.9957
# Epoch 5/49
# 91/91 [==============================] - 49s 534ms/step - loss: 0.9940 - mse: 0.9940 - val_loss: 0.9964 - val_mse: 0.9964
# Epoch 6/49
# 91/91 [==============================] - 48s 531ms/step - loss: 0.9938 - mse: 0.9938 - val_loss: 0.9969 - val_mse: 0.9969
# Epoch 7/49
# 91/91 [==============================] - 76s 843ms/step - loss: 0.9939 - mse: 0.9939 - val_loss: 0.9966 - val_mse: 0.9966
# Epoch 8/49
# 91/91 [==============================] - 99s 1s/step - loss: 0.9942 - mse: 0.9942 - val_loss: 0.9968 - val_mse: 0.9968
# Epoch 9/49
# 91/91 [==============================] - 318s 4s/step - loss: 0.9939 - mse: 0.9939 - val_loss: 0.9976 - val_mse: 0.9976
# Epoch 10/49
# 91/91 [==============================] - 97s 1s/step - loss: 0.9937 - mse: 0.9937 - val_loss: 0.9983 - val_mse: 0.9983
# Epoch 11/49
# 91/91 [==============================] - 100s 1s/step - loss: 0.9942 - mse: 0.9942 - val_loss: 0.9984 - val_mse: 0.9984
# Epoch 12/49
# 91/91 [==============================] - 94s 1s/step - loss: 0.9938 - mse: 0.9938 - val_loss: 0.9985 - val_mse: 0.9985
# Epoch 13/49
# 91/91 [==============================] - 114s 1s/step - loss: 0.9940 - mse: 0.9940 - val_loss: 0.9981 - val_mse: 0.9981
# Epoch 14/49
# 91/91 [==============================] - 121s 1s/step - loss: 0.9940 - mse: 0.9940 - val_loss: 0.9979 - val_mse: 0.9979
# Epoch 15/49
# 91/91 [==============================] - 112s 1s/step - loss: 0.9945 - mse: 0.9945 - val_loss: 0.9980 - val_mse: 0.9980
# Epoch 16/49
# 91/91 [==============================] - 109s 1s/step - loss: 0.9938 - mse: 0.9938 - val_loss: 0.9981 - val_mse: 0.9981
# Epoch 17/49
# 91/91 [==============================] - 112s 1s/step - loss: 0.9940 - mse: 0.9940 - val_loss: 0.9977 - val_mse: 0.9977
# Epoch 18/49
# 91/91 [==============================] - 116s 1s/step - loss: 0.9944 - mse: 0.9944 - val_loss: 0.9978 - val_mse: 0.9978
# Epoch 19/49
# 91/91 [==============================] - 114s 1s/step - loss: 0.9940 - mse: 0.9940 - val_loss: 0.9981 - val_mse: 0.9981
# Epoch 20/49
# 91/91 [==============================] - 113s 1s/step - loss: 0.9941 - mse: 0.9941 - val_loss: 0.9977 - val_mse: 0.9977
# Epoch 21/49
# 91/91 [==============================] - 114s 1s/step - loss: 0.9937 - mse: 0.9937 - val_loss: 0.9982 - val_mse: 0.9982
# Epoch 22/49
# 91/91 [==============================] - 113s 1s/step - loss: 0.9938 - mse: 0.9938 - val_loss: 0.9984 - val_mse: 0.9984
# Epoch 23/49
# 91/91 [==============================] - 114s 1s/step - loss: 0.9941 - mse: 0.9941 - val_loss: 0.9982 - val_mse: 0.9982
# Epoch 24/49
# 91/91 [==============================] - 115s 1s/step - loss: 0.9937 - mse: 0.9937 - val_loss: 0.9985 - val_mse: 0.9985
# Epoch 25/49
# 91/91 [==============================] - 111s 1s/step - loss: 0.9937 - mse: 0.9937 - val_loss: 0.9991 - val_mse: 0.9991
# Epoch 26/49
# 91/91 [==============================] - 113s 1s/step - loss: 0.9937 - mse: 0.9937 - val_loss: 0.9998 - val_mse: 0.9998
# Epoch 27/49
# 91/91 [==============================] - 112s 1s/step - loss: 0.9933 - mse: 0.9933 - val_loss: 1.0000 - val_mse: 1.0000
# Epoch 28/49
# 91/91 [==============================] - 116s 1s/step - loss: 0.9935 - mse: 0.9935 - val_loss: 1.0011 - val_mse: 1.0011
# Epoch 29/49
# 91/91 [==============================] - 113s 1s/step - loss: 0.9941 - mse: 0.9941 - val_loss: 1.0006 - val_mse: 1.0006
# Epoch 30/49
# 91/91 [==============================] - 101s 1s/step - loss: 0.9932 - mse: 0.9932 - val_loss: 0.9997 - val_mse: 0.9997
# Epoch 31/49
# 91/91 [==============================] - 4283s 48s/step - loss: 0.9944 - mse: 0.9944 - val_loss: 0.9994 - val_mse: 0.9994
# Epoch 32/49
# 91/91 [==============================] - 94s 1s/step - loss: 0.9933 - mse: 0.9933 - val_loss: 1.0007 - val_mse: 1.0007
# Epoch 33/49
# 91/91 [==============================] - 92s 1s/step - loss: 0.9933 - mse: 0.9933 - val_loss: 1.0005 - val_mse: 1.0005
# Epoch 34/49
# 91/91 [==============================] - 91s 1s/step - loss: 0.9933 - mse: 0.9933 - val_loss: 0.9998 - val_mse: 0.9998
# Epoch 35/49
# 91/91 [==============================] - 93s 1s/step - loss: 0.9938 - mse: 0.9938 - val_loss: 0.9998 - val_mse: 0.9998
# Epoch 39/49
# 91/91 [==============================] - 92s 1s/step - loss: 0.9936 - mse: 0.9936 - val_loss: 0.9996 - val_mse: 0.9996
# Epoch 40/49
# 91/91 [==============================] - 95s 1s/step - loss: 0.9927 - mse: 0.9927 - val_loss: 0.9998 - val_mse: 0.9998
# Epoch 41/49
# 91/91 [==============================] - 97s 1s/step - loss: 0.9942 - mse: 0.9942 - val_loss: 0.9994 - val_mse: 0.9994
# Epoch 42/49
# 91/91 [==============================] - 91s 1000ms/step - loss: 0.9944 - mse: 0.9944 - val_loss: 0.9987 - val_mse: 0.9987
# Epoch 43/49
# 91/91 [==============================] - 86s 947ms/step - loss: 0.9933 - mse: 0.9933 - val_loss: 0.9997 - val_mse: 0.9997
# Epoch 44/49
# 91/91 [==============================] - 87s 951ms/step - loss: 0.9932 - mse: 0.9932 - val_loss: 1.0003 - val_mse: 1.0003
# Epoch 45/49
# 91/91 [==============================] - 87s 953ms/step - loss: 0.9927 - mse: 0.9927 - val_loss: 1.0029 - val_mse: 1.0029
# Epoch 46/49
# 91/91 [==============================] - 89s 981ms/step - loss: 0.9933 - mse: 0.9933 - val_loss: 1.0030 - val_mse: 1.0030
# Epoch 47/49
# 91/91 [==============================] - 87s 962ms/step - loss: 0.9938 - mse: 0.9938 - val_loss: 1.0026 - val_mse: 1.0026
# Epoch 48/49
# 91/91 [==============================] - 90s 988ms/step - loss: 0.9930 - mse: 0.9930 - val_loss: 1.0029 - val_mse: 1.0029
# Epoch 49/49
# 91/91 [==============================] - 90s 992ms/step - loss: 0.9933 - mse: 0.9933 - val_loss: 1.0029 - val_mse: 1.0029

# %%
train_pred = model_1.predict(x_train)
test_pred = model_1.predict(x_test)
# Out:
# 29/29 [==============================] - 85s 665ms/step
# 6/6 [==============================] - 5s 723ms/step

# %%
train_pred.shape
# Out:
# (904, 1)

# %%
y_train.shape, train_pred.shape
# Out:
# ((904,), (904, 1))

# %% [markdown]
# # Accuracy of Model

# %%
def accuracy_LSTM(data_1, data_2):
    x = (np.sign(np.array(data_1)) == np.sign(np.array(data_2)))
    
    return print(sum(x[0]) / len(x))

# %%
accuracy_LSTM(train_pred, y_train)
# Out:
# 0.0

# %%
accuracy_LSTM(test_pred, y_test)
# Out:
# 0.0

# %%
rmse = np.sqrt(mean_squared_error(y_true = y_train, y_pred = train_pred))
print("RMSE: {:.2f}".format(rmse))
# Out:
# RMSE: 1.00

# %%
rmse = np.sqrt(mean_squared_error(y_true = y_test, y_pred = test_pred))
print("RMSE: {:.2f}".format(rmse))
# Out:
# RMSE: 0.98

# %%
train_pred = scaler.inverse_transform(train_pred)
test_pred = scaler.inverse_transform(test_pred)
train_pred.shape, test_pred.shape
# Out:
# ((904, 1), (188, 1))

# %%
df3.shape
# Out:
# (1194, 1)

# %%
import numpy
### Plotting 
# shift train predictions for plotting
look_back = 50
trainPredictPlot = numpy.empty_like(df3)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_pred)+look_back, :] = train_pred

# %%
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df3)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_pred)+(look_back*2)+1:len(df3)-1, :] = test_pred

# %%
testPredictPlot
# Out:
# array([[       nan],
#        [       nan],
#        [       nan],
#        ...,
#        [0.00128194],
#        [0.00123383],
#        [       nan]])

# %%
df3 = scaler.inverse_transform(df3)

# %% [markdown]
# # Visualization of Results

# %%
# plot baseline and predictions
plt.figure(figsize = (18,10))
plt.plot((df3),label = "Original Dataset ")
plt.plot((trainPredictPlot),label= "Prediction X_train ")
plt.plot((testPredictPlot),label = "Prediction X_test ")
plt.xlabel('Dateset', fontsize=18)
plt.ylabel('Return USD ($)', fontsize=18)
plt.legend()
plt.show()

# %%
len(train_data),len(test_data)
# Out:
# (955, 239)

# %%
time_stamp = 50
var = len(test_data)-time_stamp
x_input = test_data[var:].reshape(1,-1)
x_input.shape
# Out:
# (1, 50)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 1 days
from numpy import array

lst_output=[]
n_steps=50
i=0
while(i<1):
    
    if(len(temp_input)>n_steps):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        #print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model_1.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model_1.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.07707042]
# 51

# %%
lst_output = scaler.inverse_transform(lst_output)

# %%
day_new=np.arange(1,51)
day_pred=np.arange(51,52)

# %%
import matplotlib.pyplot as plt

# %%
len(df3)
# Out:
# 1194

# %% [markdown]
# # Ploting Predicted Value

# %%
var_1 = len(df3)-time_stamp
plt.figure(figsize = (20,10))
plt.plot(day_new,(df3[var_1:]))
plt.scatter(day_pred,(lst_output), c = "r")
plt.xlabel('Dateset', fontsize=18)
plt.ylabel('Return USD ($)', fontsize=18)
# Out:
# Text(0, 0.5, 'Return USD ($)')

# %%
plt.figure(figsize = (20,10))
df3 = df3.tolist()
df3.extend((lst_output))
plt.plot((df3[var_1:]))
plt.xlabel('Dateset', fontsize=18)
plt.ylabel('Return USD ($)', fontsize=18)
# Out:
# Text(0, 0.5, 'Return USD ($)')

# %% [markdown]
# # Loading New Data for Cross Checking

# %%
check_df = yf.download('^NSEI',start="2015-12-01", end="2016-01-04",interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
check_df["Close"].tail(10)
# Out:
# Date
# 2015-12-17 00:00:00+05:30    7844.350098
# 2015-12-18 00:00:00+05:30    7761.950195
# 2015-12-21 00:00:00+05:30    7834.450195
# 2015-12-22 00:00:00+05:30    7786.100098
# 2015-12-23 00:00:00+05:30    7865.950195
# 2015-12-24 00:00:00+05:30    7861.049805
# 2015-12-28 00:00:00+05:30    7925.149902
# 2015-12-29 00:00:00+05:30    7928.950195
# 2015-12-30 00:00:00+05:30    7896.250000
# 2015-12-31 00:00:00+05:30    7946.350098
# Name: Close, dtype: float64

# %%
check_df["Return"] = check_df.Close.pct_change()

# %%
check_df1 = check_df["Return"].dropna()
check_df1,df1[1425:]
# Out:
# (Date
#  2015-12-02 00:00:00+05:30   -0.002960
#  2015-12-03 00:00:00+05:30   -0.008473
#  2015-12-04 00:00:00+05:30   -0.010459
#  2015-12-07 00:00:00+05:30   -0.002120
#  2015-12-08 00:00:00+05:30   -0.008203
#  2015-12-09 00:00:00+05:30   -0.011582
#  2015-12-10 00:00:00+05:30    0.009300
#  2015-12-11 00:00:00+05:30   -0.009482
#  2015-12-14 00:00:00+05:30    0.005203
#  2015-12-15 00:00:00+05:30    0.006647
#  2015-12-16 00:00:00+05:30    0.006493
#  2015-12-17 00:00:00+05:30    0.012057
#  2015-12-18 00:00:00+05:30   -0.010504
#  2015-12-21 00:00:00+05:30    0.009340
#  2015-12-22 00:00:00+05:30   -0.006171
#  2015-12-23 00:00:00+05:30    0.010255
#  2015-12-24 00:00:00+05:30   -0.000623
#  2015-12-28 00:00:00+05:30    0.008154
#  2015-12-29 00:00:00+05:30    0.000480
#  2015-12-30 00:00:00+05:30   -0.004124
#  2015-12-31 00:00:00+05:30    0.006345
#  Name: Return, dtype: float64,
#  Empty DataFrame
#  Columns: [Close, Return, Log_Return]
#  Index: [])

# %%
for_adding_date = yf.download('^NSEI',start="2011-01-31", end="2015-12-31",interval='1d')
for_adding_date.shape
for_adding_date.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                   Open         High          Low        Close  \
# Date
# 2015-12-23 00:00:00+05:30  7830.450195  7871.450195  7826.100098  7865.950195
# 2015-12-24 00:00:00+05:30  7888.750000  7888.750000  7835.500000  7861.049805
# 2015-12-28 00:00:00+05:30  7863.200195  7937.200195  7863.000000  7925.149902
# 2015-12-29 00:00:00+05:30  7929.200195  7942.149902  7902.750000  7928.950195
# 2015-12-30 00:00:00+05:30  7938.600098  7944.750000  7889.850098  7896.250000
#
#                              Adj Close  Volume
# Date
# 2015-12-23 00:00:00+05:30  7865.950195  117900
# 2015-12-24 00:00:00+05:30  7861.049805   93500
# 2015-12-28 00:00:00+05:30  7925.149902  122900
# 2015-12-29 00:00:00+05:30  7928.950195  113000
# 2015-12-30 00:00:00+05:30  7896.250000  106800

# %%
df4 = pd.DataFrame(df3)

# %%
df4 = df4.set_index(for_adding_date.index)

# %%
# Ploting Final comparision 
plt.figure(figsize = (20,10))
plt.subplot(3,1,1)
plt.plot(check_df1,label = "New Data")
plt.ylabel('Return USD ($)', fontsize=18)
plt.legend()
plt.subplot(3,1,2)
plt.plot(df2[var_1+30:], label = "Original Data", color = "r")
plt.ylabel('Return USD ($)', fontsize=18)
plt.legend()
plt.subplot(3,1,3)
plt.plot(df4[var_1+30:], label = "Predicted Data", c = "g")
plt.xlabel('Dateset', fontsize=18)
plt.ylabel('Return USD ($)', fontsize=18)
plt.legend()
