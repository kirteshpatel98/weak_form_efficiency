# %%
import yfinance as yf
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
sp500=yf.download('^GSPC',start="2022-02-01", end="2023-02-01",interval='1h')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
sp500['Adj Close'].plot( title='hourly')
# Out:
# <AxesSubplot:title={'center':'hourly'}>

# %%
sp500.head()
# Out:
#                             Open         High          Low        Close  \
# 2022-02-01 09:30:00  4519.569824  4525.560059  4483.529785  4501.950195
# 2022-02-01 10:30:00  4501.970215  4522.270020  4493.779785  4512.879883
# 2022-02-01 11:30:00  4512.919922  4523.939941  4504.540039  4514.740234
# 2022-02-01 12:30:00  4514.729980  4518.810059  4504.450195  4517.580078
# 2022-02-01 13:30:00  4517.580078  4522.609863  4509.439941  4515.500000
#
#                        Adj Close     Volume
# 2022-02-01 09:30:00  4501.950195          0
# 2022-02-01 10:30:00  4512.879883  349426580
# 2022-02-01 11:30:00  4514.740234  261984302
# 2022-02-01 12:30:00  4517.580078  207959000
# 2022-02-01 13:30:00  4515.500000  233552000

# %%
# dicket fuller test sp500

# %%
adf_sp500, pvalue_sp500, usedlag_, nobs_, critical_values_sp500, icbest_ = adfuller(sp500['Adj Close'])
adf_sp500
# Out:
# -2.2214889653023873

# %%
pvalue_sp500 # failed
# Out:
# 0.1985388445604488

# %%
critical_values_sp500
# Out:
# {'1%': -3.434085825118835,
#  '5%': -2.8631901587664874,
#  '10%': -2.5676484953770067}

# %%
# decomposition into trend, seasonal and residual

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
sp500_decomposition = seasonal_decompose(x=sp500['Adj Close'], model='additive', period=30)

# %%
sp500_trend = sp500_decomposition.trend
sp500_seasonal = sp500_decomposition.seasonal
sp500_residual = sp500_decomposition.resid

# %%
sp500_trend.plot( title='hourly')
# Out:
# <AxesSubplot:title={'center':'hourly'}>

# %%
sp500_seasonal.plot( title='hourly')
# Out:
# <AxesSubplot:title={'center':'hourly'}>

# %%
sp500_residual.plot( title='hourly')
# Out:
# <AxesSubplot:title={'center':'hourly'}>

# %%
# dickey fuller of residual
sp500_residual=sp500_residual[~np.isnan(sp500_residual)]

# %%
adf_sp500_residual, pvalue_sp500_residual, usedlag_, nobs_, critical_values_sp500_residual, icbest_ = adfuller(sp500_residual)
adf_sp500_residual
# Out:
# -11.799754087226713

# %%
pvalue_sp500_residual # test passed
# Out:
# 9.391932632147616e-22

# %%
critical_values_sp500_residual
# Out:
# {'1%': -3.4342002032721437,
#  '5%': -2.8632406484200064,
#  '10%': -2.5676753800009053}

# %%
# variance and mean test
sp500_residual.shape
# Out:
# (1724,)

# %%
chunks_sp500_residual = np.split(sp500_residual, indices_or_sections=4)

# %%
np.mean(chunks_sp500_residual, axis=1)
# Out:
# array([-0.69318405,  0.06098551, -0.11616244,  0.51713433])

# %%
np.var(chunks_sp500_residual, axis=1)
# Out:
# array([1359.87145428, 1385.65393196, 1021.29481479,  924.4039926 ])

# %%
# histogram

# %%
sp500['Adj Close'].hist() # no normal dist
# Out:
# <AxesSubplot:>

# %%
# log transform

# %%
sp500_log = np.log(sp500['Adj Close'])

# %%
sp500_log.plot( title='hourly')
# Out:
# <AxesSubplot:title={'center':'hourly'}>

# %%
adf_sp500_log, pvalue_sp500_log, usedlag_, nobs_, critical_values_sp500_log, icbest_ = adfuller(sp500_log)
adf_sp500_log
# Out:
# -2.2329548193628606

# %%
pvalue_sp500_log
# Out:
# 0.19450285556089497

# %%
critical_values_sp500_log
# Out:
# {'1%': -3.434085825118835,
#  '5%': -2.8631901587664874,
#  '10%': -2.5676484953770067}

# %%
# difference

# %%
sp500_diff=sp500['Adj Close'].diff(periods=1)[~np.isnan(sp500['Adj Close'].diff(periods=1))]

# %%
sp500_diff.plot( title='hourly')
# Out:
# <AxesSubplot:title={'center':'hourly'}>

# %%
# variance, mean test
sp500_diff
# Out:
# 2022-02-01 10:30:00    10.929688
# 2022-02-01 11:30:00     1.860352
# 2022-02-01 12:30:00     2.839844
# 2022-02-01 13:30:00    -2.080078
# 2022-02-01 14:30:00    21.959961
#                          ...
# 2023-01-31 11:30:00     2.620117
# 2023-01-31 12:30:00     2.599854
# 2023-01-31 13:30:00     6.300049
# 2023-01-31 14:30:00    -5.709961
# 2023-01-31 15:30:00    26.890137
# Name: Adj Close, Length: 1753, dtype: float64

# %%
sp500_diff.shape
# Out:
# (1753,)

# %%
chunks_sp500_diff = np.split(sp500_diff[1:], indices_or_sections=6) # for week data change it to 13
np.mean(chunks_sp500_diff,axis=1)
# Out:
# array([ 0.06650658, -1.40965626,  0.05246515, -1.68664384,  1.06376752,
#         0.41948627])

# %%
np.var(chunks_sp500_diff,axis=1)
# Out:
# array([465.96708381, 584.34529512, 543.094541  , 356.34629722,
#        531.73704439, 288.90179075])

# %%
# adf test

# %%
adf_sp500_diff, pvalue_sp500_diff, usedlag_, nobs_, critical_values_sp500_diff, icbest_ = adfuller(sp500_diff)
adf_sp500_diff
# Out:
# -41.07650897969508

# %%
pvalue_sp500_diff # pass
# Out:
# 0.0
