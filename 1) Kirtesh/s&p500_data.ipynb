# %%
import yfinance as yf

# %%
sp500=yf.download('^GSPC',start="2022-02-01", end="2023-02-01",interval='1w')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ^GSPC: Invalid input - interval=1w is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]

# %%
sp500['Adj Close'].max()
# Out:
# nan

# %%
sp500['Adj Close'].plot( title='Weekly')
# Out:
# <AxesSubplot:title={'center':'Weekly'}, xlabel='Date'>

# %%
sp500['Adj Close'].plot.hist( title='Weekly',bins=50)
# Out:
# <AxesSubplot:title={'center':'Weekly'}, ylabel='Frequency'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot
plot_acf(sp500['Adj Close'], lags=5, title='Aladin ')
# Out:
# C:\Users\hp\miniconda3\envs\kirtesh\lib\site-packages\statsmodels\tsa\stattools.py:467: RuntimeWarning: Mean of empty slice.
#   xo = x - x.mean()
# C:\Users\hp\miniconda3\envs\kirtesh\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot
# ----> 2 plot_acf(sp500['Adj Close'], lags=5, title='Aladin ')
#
# File ~\miniconda3\envs\kirtesh\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# ...

# %%
sp500

# %%
sp500['Adj Close'].rolling(7).mean().plot()
