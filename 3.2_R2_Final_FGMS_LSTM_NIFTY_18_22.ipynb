# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\agarw\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: ipython in c:\users\agarw\anaconda3\lib\site-packages (from keras-tuner) (8.2.0)
# Requirement already satisfied: requests in c:\users\agarw\anaconda3\lib\site-packages (from keras-tuner) (2.27.1)
# Requirement already satisfied: packaging in c:\users\agarw\anaconda3\lib\site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: kt-legacy in c:\users\agarw\anaconda3\lib\site-packages (from keras-tuner) (1.0.4)
# Requirement already satisfied: tensorflow>=2.0 in c:\users\agarw\anaconda3\lib\site-packages (from keras-tuner) (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: setuptools in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (61.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (15.0.6.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.30.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.6.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.6.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.19.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.12.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.11.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.21.5)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (23.1.21)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\agarw\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.42.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\agarw\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.3.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.33.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\agarw\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\agarw\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\agarw\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\agarw\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\agarw\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\agarw\anaconda3\lib\site-packages (from requests->keras-tuner) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agarw\anaconda3\lib\site-packages (from requests->keras-tuner) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agarw\anaconda3\lib\site-packages (from requests->keras-tuner) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.0->keras-tuner) (3.2.2)
# Requirement already satisfied: colorama in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.4.4)
# Requirement already satisfied: matplotlib-inline in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.1.2)
# Requirement already satisfied: backcall in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: decorator in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (3.0.20)
# Requirement already satisfied: stack-data in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: traitlets>=5 in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\agarw\anaconda3\lib\site-packages (from ipython->keras-tuner) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\agarw\anaconda3\lib\site-packages (from jedi>=0.16->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\agarw\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\agarw\anaconda3\lib\site-packages (from packaging->keras-tuner) (3.0.4)
# Requirement already satisfied: executing in c:\users\agarw\anaconda3\lib\site-packages (from stack-data->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\agarw\anaconda3\lib\site-packages (from stack-data->ipython->keras-tuner) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\agarw\anaconda3\lib\site-packages (from stack-data->ipython->keras-tuner) (0.2.2)

# %% [markdown]
# # LSTM Model_NIFTY FROM 2018 TO 2022

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller, acf, pacf
import yfinance as yf
import math
from sklearn.metrics import mean_squared_error
import pandas_datareader as pdr
import os
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Data Acquisition

# %%
df = yf.download('^NSEI',start="2018-01-31", end="2022-12-31",interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.tail()
# Out:
#                                    Open          High           Low  \
# Date
# 2022-12-26 00:00:00+05:30  17830.400391  18084.099609  17774.250000
# 2022-12-27 00:00:00+05:30  18089.800781  18149.250000  17967.449219
# 2022-12-28 00:00:00+05:30  18084.750000  18173.099609  18068.349609
# 2022-12-29 00:00:00+05:30  18045.699219  18229.699219  17992.800781
# 2022-12-30 00:00:00+05:30  18259.099609  18265.250000  18080.300781
#
#                                   Close     Adj Close  Volume
# Date
# 2022-12-26 00:00:00+05:30  18014.599609  18014.599609  176700
# 2022-12-27 00:00:00+05:30  18132.300781  18132.300781  214300
# 2022-12-28 00:00:00+05:30  18122.500000  18122.500000  193900
# 2022-12-29 00:00:00+05:30  18191.000000  18191.000000  281100
# 2022-12-30 00:00:00+05:30  18105.300781  18105.300781  192000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1212 entries, 2018-01-31 00:00:00+05:30 to 2022-12-30 00:00:00+05:30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1212 non-null   float64
#  1   High       1212 non-null   float64
#  2   Low        1212 non-null   float64
#  3   Close      1212 non-null   float64
#  4   Adj Close  1212 non-null   float64
#  5   Volume     1212 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 66.3 KB

# %%
df
# Out:
#                                    Open          High           Low  \
# Date
# 2018-01-31 00:00:00+05:30  11018.799805  11058.500000  10979.299805
# 2018-02-01 00:00:00+05:30  11044.549805  11117.349609  10878.799805
# 2018-02-02 00:00:00+05:30  10938.200195  10954.950195  10736.099609
# 2018-02-05 00:00:00+05:30  10604.299805  10702.750000  10586.799805
# 2018-02-06 00:00:00+05:30  10295.150391  10594.150391  10276.299805
# ...                                 ...           ...           ...
# 2022-12-26 00:00:00+05:30  17830.400391  18084.099609  17774.250000
# 2022-12-27 00:00:00+05:30  18089.800781  18149.250000  17967.449219
# 2022-12-28 00:00:00+05:30  18084.750000  18173.099609  18068.349609
# 2022-12-29 00:00:00+05:30  18045.699219  18229.699219  17992.800781
# 2022-12-30 00:00:00+05:30  18259.099609  18265.250000  18080.300781
#
#                                   Close     Adj Close  Volume
# Date
# 2018-01-31 00:00:00+05:30  11027.700195  11027.700195  245900
# 2018-02-01 00:00:00+05:30  11016.900391  11016.900391  306200
# 2018-02-02 00:00:00+05:30  10760.599609  10760.599609  282700
# 2018-02-05 00:00:00+05:30  10666.549805  10666.549805  240100
# 2018-02-06 00:00:00+05:30  10498.250000  10498.250000  266500
# ...                                 ...           ...     ...
# 2022-12-26 00:00:00+05:30  18014.599609  18014.599609  176700
# 2022-12-27 00:00:00+05:30  18132.300781  18132.300781  214300
# 2022-12-28 00:00:00+05:30  18122.500000  18122.500000  193900
# 2022-12-29 00:00:00+05:30  18191.000000  18191.000000  281100
# 2022-12-30 00:00:00+05:30  18105.300781  18105.300781  192000
#
# [1212 rows x 6 columns]

# %% [markdown]
# # Data Preparation

# %%
df["Return"] = df["Adj Close"].pct_change()

# %%
df1 = df.drop(columns = ["Open","High","Low","Adj Close", "Volume"])

# %%
df1
# Out:
#                                   Close    Return
# Date
# 2018-01-31 00:00:00+05:30  11027.700195       NaN
# 2018-02-01 00:00:00+05:30  11016.900391 -0.000979
# 2018-02-02 00:00:00+05:30  10760.599609 -0.023264
# 2018-02-05 00:00:00+05:30  10666.549805 -0.008740
# 2018-02-06 00:00:00+05:30  10498.250000 -0.015778
# ...                                 ...       ...
# 2022-12-26 00:00:00+05:30  18014.599609  0.011670
# 2022-12-27 00:00:00+05:30  18132.300781  0.006534
# 2022-12-28 00:00:00+05:30  18122.500000 -0.000541
# 2022-12-29 00:00:00+05:30  18191.000000  0.003780
# 2022-12-30 00:00:00+05:30  18105.300781 -0.004711
#
# [1212 rows x 2 columns]

# %%
df1["Log_Return"] = np.log(1+df1["Return"])

# %%
df1 = df1.dropna()

# %%
df2 = df1["Log_Return"]

# %%
plt.figure(figsize=(16,6))
plt.title('Log Return History')
plt.plot(df2)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Return USD ($)', fontsize=18)
plt.show()

# %%
# Create a histogram of stock data
plt.figure(figsize = (15,6))
plt.hist(df2, bins=30, alpha=0.5, color='blue')

# Add a vertical line for the mean
plt.axvline(df2.mean(), color='red', linestyle='dashed', linewidth=2)

# Add labels and title
plt.xlabel("Date")
plt.ylabel("Log_Return")
plt.title('Histogram of Stock Data')

# Show the plot
plt.show()

# %% [markdown]
# # Scaling Data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df3 = scaler.fit_transform(np.array(df2).reshape(-1, 1))

# %%
df3
# Out:
# array([[-0.11163367],
#        [-1.92443708],
#        [-0.73832158],
#        ...,
#        [-0.0763447 ],
#        [ 0.27026411],
#        [-0.412361  ]])

# %% [markdown]
# # Train Test Split

# %%
train_size = int(len(df3)*0.8)
test_size = len(df3)-train_size
train_size,test_size
# Out:
# (968, 243)

# %%
train_data,test_data = df3[0:train_size],df3[train_size:]

# %%
train_data.shape,test_data.shape
# Out:
# ((968, 1), (243, 1))

# %%
def creat_dataset(data, time_stamp):
    data_x, data_y = [], []
    for i in range(len(data)-time_stamp-1):
        a = data[i: i + time_stamp, 0]
        data_x.append(a)
        b = data[i+time_stamp,0]
        data_y.append(b)
    return data_x, data_y

# %%
x_train, y_train = creat_dataset(train_data,50)
x_test, y_test = creat_dataset(test_data,50)

# %%
x_train = np.asarray(x_train)
x_test = np.asarray(x_test)
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)
x_train,x_test
# Out:
# (array([[-0.11163367, -1.92443708, -0.73832158, ...,  0.13556677,
#           0.33237868,  0.12227567],
#         [-1.92443708, -0.73832158, -1.31090153, ...,  0.33237868,
#           0.12227567, -0.20448029],
#         [-0.73832158, -1.31090153, -0.19801734, ...,  0.12227567,
#          -0.20448029,  0.26503415],
#         ...,
#         [-0.31275989,  0.0136652 ,  0.59858758, ..., -0.07796164,
#           0.66516076,  1.21520984],
#         [ 0.0136652 ,  0.59858758, -0.28600653, ...,  0.66516076,
#           1.21520984,  0.78154546],
#         [ 0.59858758, -0.28600653, -1.60897329, ...,  1.21520984,
#           0.78154546,  0.5068565 ]]),
#  array([[ 0.82237785,  0.20086546,  0.66104086, ..., -0.82445933,
#           0.89079591, -0.35770896],
#         [ 0.20086546,  0.66104086,  0.16739192, ...,  0.89079591,
#          -0.35770896, -0.13967518],
#         [ 0.66104086,  0.16739192, -0.04192533, ..., -0.35770896,
#          -0.13967518, -0.35899509],
#         ...,
#         [ 0.77231863,  0.5545742 ,  0.77600976, ..., -0.3503323 ,
#          -1.46657644,  0.89940735],
#         [ 0.5545742 ,  0.77600976,  0.08328053, ..., -1.46657644,
#           0.89940735,  0.49041765],
#         [ 0.77600976,  0.08328053,  0.20397926, ...,  0.89940735,
#           0.49041765, -0.0763447 ]]))

# %% [markdown]
# # Find the correlation in b/w daily Returns

# %%
import seaborn as sns 
from sklearn.preprocessing import Normalizer
normalizedx_train = Normalizer().fit_transform(x_train)

normalizedx_train = pd.DataFrame(normalizedx_train)
normalizedx_train
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.022414 -0.386386 -0.148239 -0.263201 -0.039758  0.146891 -0.193631
# 1   -0.386158 -0.148152 -0.263045 -0.039734  0.146804 -0.193516  0.123656
# 2   -0.160343 -0.284692 -0.043004  0.158885 -0.209441  0.133832 -0.071589
# 3   -0.288411 -0.043566  0.160960 -0.212178  0.135580 -0.072525  0.067691
# 4   -0.045481  0.168035 -0.221504  0.141539 -0.075712  0.070666 -0.171398
# ..        ...       ...       ...       ...       ...       ...       ...
# 912 -0.120113 -0.072668 -0.053709  0.002347  0.102792 -0.049114 -0.276300
# 913 -0.072718 -0.053746  0.002348  0.102863 -0.049148 -0.276491 -0.149926
# 914 -0.052745  0.002305  0.100947 -0.048233 -0.271341 -0.147134  0.190870
# 915  0.002288  0.100219 -0.047885 -0.269383 -0.146072  0.189492 -0.036084
# 916  0.099860 -0.047713 -0.268419 -0.145549  0.188814 -0.035954 -0.050339
#
#            7         8         9   ...        40        41        42  \
# 0    0.123729 -0.066185  0.061774  ... -0.191281  0.303801  0.003469
# 1   -0.066146  0.061737 -0.149741  ...  0.303621  0.003467  0.067750
# 2    0.066818 -0.162064 -0.130967  ...  0.003752  0.073325  0.031316
# 3   -0.164181 -0.132678 -0.037927  ...  0.074283  0.031726  0.018068
# 4   -0.138510 -0.039594  0.058328  ...  0.033120  0.018862  0.065825
# ..        ...       ...       ...  ...       ...       ...       ...
# 912 -0.149823  0.194358 -0.037010  ... -0.217842 -0.310401  0.123850
# 913  0.194492 -0.037036 -0.051853  ... -0.310615  0.123935  0.145512
# 914 -0.036346 -0.050887  0.060873  ...  0.121627  0.142801  0.087762
# 915 -0.050520  0.060434  0.107962  ...  0.141771  0.087129 -0.059874
# 916  0.060217  0.107575 -0.023530  ...  0.086817 -0.059659  0.059397
#
#            43        44        45        46        47        48        49
# 0    0.067790  0.028952  0.016489  0.057542  0.027219  0.066735  0.024550
# 1    0.028935  0.016479  0.057508  0.027203  0.066695  0.024536 -0.041031
# 2    0.017835  0.062240  0.029441  0.072184  0.026555 -0.044408  0.057558
# 3    0.063053  0.029826  0.073127  0.026902 -0.044988  0.058310 -0.009330
# 4    0.031137  0.076341  0.028084 -0.046965  0.060873 -0.009740  0.028487
# ..        ...       ...       ...       ...       ...       ...       ...
# 912  0.145411  0.089366 -0.061411  0.061141  0.112563 -0.021393 -0.013388
# 913  0.089428 -0.061453  0.061183  0.112641 -0.021408 -0.013397  0.114303
# 914 -0.060309  0.060043  0.110543 -0.021009 -0.013148  0.112174  0.204936
# 915  0.059610  0.109745 -0.020858 -0.013053  0.111365  0.203457  0.130851
# 916  0.109352 -0.020783 -0.013006  0.110966  0.202729  0.130382  0.084557
#
# [917 rows x 50 columns]

# %% [markdown]
# # Pearson Correlation

# %%
# plot correlation heatmap
plt.figure(figsize = (40,20))
sns.heatmap(normalizedx_train.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1],1)
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1],1)

# %%
x_train.shape, x_test.shape
# Out:
# ((917, 50, 1), (192, 50, 1))

# %%
# Building Model

# %%
import keras_tuner
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM
from kerastuner import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
import tensorflow as tf
# Out:
# C:\Users\agarw\AppData\Local\Temp\ipykernel_18820\881150544.py:5: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner import RandomSearch

# %% [markdown]
# # Hyperparameter Tuning

# %%
my_learning_rate = .00001

# %%
def build_model(hp):
    model = Sequential()
    model.add(LSTM(hp.Int('input_unit',min_value=32,max_value=512,step=32),return_sequences=True, input_shape=(50,1)))
    for i in range(hp.Int('n_layers', 1, 4)):
        model.add(LSTM(hp.Int(f'lstm_{i}_units',min_value=32,max_value=512,step=32),return_sequences=True))
    model.add(LSTM(hp.Int('layer_2_neurons',min_value=32,max_value=512,step=32)))
    model.add(Dropout(hp.Float('Dropout_rate',min_value=0,max_value=0.5,step=0.1)))
    model.add(Dense(1, activation=hp.Choice('dense_activation',values=['relu', 'sigmoid'],default='relu')))
    model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.RMSprop(learning_rate=my_learning_rate),metrics = ['mse'])
    return model

# %%
tuner_search = RandomSearch(
    build_model,
    objective='mse',
    max_trials=1,
    directory='output',
    project_name='R1_Final_FGMS_LSTM_NIFTY_New-data_model_2'
)

# %%
tuner_search.search(
        x=x_train,
        y=y_train,
        epochs=30,
        batch_size=20,
        validation_data=(x_test,y_test),
)
# Out:
# Trial 1 Complete [04h 48m 48s]
# mse: 1.0876834392547607
#
# Best mse So Far: 1.0876834392547607
# Total elapsed time: 04h 48m 48s
# INFO:tensorflow:Oracle triggered exit

# %%
model_1=tuner_search.get_best_models(num_models=1)[0]

# %%
# Fitting Model

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 96)            37632
#
#  lstm_1 (LSTM)               (None, 50, 352)           632192
#
#  lstm_2 (LSTM)               (None, 50, 32)            49280
#
#  lstm_3 (LSTM)               (None, 288)               369792
#
#  dropout (Dropout)           (None, 288)               0
#
#  dense (Dense)               (None, 1)                 289
#
# =================================================================
# Total params: 1,089,185
# Trainable params: 1,089,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_1.fit(x=x_train,
        y=y_train,
        epochs=49,
        batch_size=10,
        validation_data=(x_test,x_test),
)
# Out:
# Epoch 1/49
# 92/92 [==============================] - 947s 2s/step - loss: 1.0883 - mse: 1.0883 - val_loss: 0.7828 - val_mse: 0.7828
# Epoch 2/49
# 92/92 [==============================] - 92s 998ms/step - loss: 1.0884 - mse: 1.0884 - val_loss: 0.7829 - val_mse: 0.7829
# Epoch 3/49
# 92/92 [==============================] - 98s 1s/step - loss: 1.0888 - mse: 1.0888 - val_loss: 0.7828 - val_mse: 0.7828
# Epoch 4/49
# 92/92 [==============================] - 92s 998ms/step - loss: 1.0883 - mse: 1.0883 - val_loss: 0.7827 - val_mse: 0.7827
# Epoch 5/49
# 92/92 [==============================] - 92s 1s/step - loss: 1.0882 - mse: 1.0882 - val_loss: 0.7828 - val_mse: 0.7828
# Epoch 6/49
# 92/92 [==============================] - 90s 982ms/step - loss: 1.0883 - mse: 1.0883 - val_loss: 0.7829 - val_mse: 0.7829
# Epoch 7/49
# 92/92 [==============================] - 90s 981ms/step - loss: 1.0881 - mse: 1.0881 - val_loss: 0.7828 - val_mse: 0.7828
# Epoch 8/49
# 92/92 [==============================] - 92s 1s/step - loss: 1.0884 - mse: 1.0884 - val_loss: 0.7827 - val_mse: 0.7827
# Epoch 9/49
# 92/92 [==============================] - 93s 1s/step - loss: 1.0886 - mse: 1.0886 - val_loss: 0.7828 - val_mse: 0.7828
# Epoch 10/49
# 92/92 [==============================] - 91s 988ms/step - loss: 1.0877 - mse: 1.0877 - val_loss: 0.7829 - val_mse: 0.7829
# Epoch 11/49
# 92/92 [==============================] - 89s 969ms/step - loss: 1.0876 - mse: 1.0876 - val_loss: 0.7829 - val_mse: 0.7829
# Epoch 12/49
# 92/92 [==============================] - 91s 988ms/step - loss: 1.0876 - mse: 1.0876 - val_loss: 0.7830 - val_mse: 0.7830
# Epoch 13/49
# 92/92 [==============================] - 93s 1s/step - loss: 1.0874 - mse: 1.0874 - val_loss: 0.7830 - val_mse: 0.7830
# Epoch 14/49
# 92/92 [==============================] - 92s 1s/step - loss: 1.0879 - mse: 1.0879 - val_loss: 0.7831 - val_mse: 0.7831
# Epoch 15/49
# 92/92 [==============================] - 94s 1s/step - loss: 1.0880 - mse: 1.0880 - val_loss: 0.7830 - val_mse: 0.7830
# Epoch 16/49
# 92/92 [==============================] - 93s 1s/step - loss: 1.0872 - mse: 1.0872 - val_loss: 0.7832 - val_mse: 0.7832
# Epoch 17/49
# 92/92 [==============================] - 92s 1s/step - loss: 1.0876 - mse: 1.0876 - val_loss: 0.7833 - val_mse: 0.7833
# Epoch 18/49
# 92/92 [==============================] - 90s 975ms/step - loss: 1.0874 - mse: 1.0874 - val_loss: 0.7833 - val_mse: 0.7833
# Epoch 19/49
# 92/92 [==============================] - 90s 980ms/step - loss: 1.0882 - mse: 1.0882 - val_loss: 0.7832 - val_mse: 0.7832
# Epoch 20/49
# 92/92 [==============================] - 91s 992ms/step - loss: 1.0868 - mse: 1.0868 - val_loss: 0.7832 - val_mse: 0.7832
# Epoch 21/49
# 92/92 [==============================] - 92s 998ms/step - loss: 1.0873 - mse: 1.0873 - val_loss: 0.7832 - val_mse: 0.7832
# Epoch 22/49
# 92/92 [==============================] - 95s 1s/step - loss: 1.0872 - mse: 1.0872 - val_loss: 0.7832 - val_mse: 0.7832
# Epoch 23/49
# 92/92 [==============================] - 90s 979ms/step - loss: 1.0866 - mse: 1.0866 - val_loss: 0.7833 - val_mse: 0.7833
# Epoch 24/49
# 92/92 [==============================] - 4256s 47s/step - loss: 1.0876 - mse: 1.0876 - val_loss: 0.7833 - val_mse: 0.7833
# Epoch 25/49
# 92/92 [==============================] - 85s 927ms/step - loss: 1.0867 - mse: 1.0867 - val_loss: 0.7836 - val_mse: 0.7836
# Epoch 26/49
# 92/92 [==============================] - 78s 849ms/step - loss: 1.0865 - mse: 1.0865 - val_loss: 0.7836 - val_mse: 0.7836
# Epoch 27/49
# 92/92 [==============================] - 78s 852ms/step - loss: 1.0873 - mse: 1.0873 - val_loss: 0.7834 - val_mse: 0.7834
# Epoch 28/49
# 92/92 [==============================] - 79s 857ms/step - loss: 1.0866 - mse: 1.0866 - val_loss: 0.7837 - val_mse: 0.7837
# Epoch 29/49
# 92/92 [==============================] - 80s 874ms/step - loss: 1.0878 - mse: 1.0878 - val_loss: 0.7837 - val_mse: 0.7837
# Epoch 30/49
# 92/92 [==============================] - 80s 875ms/step - loss: 1.0861 - mse: 1.0861 - val_loss: 0.7838 - val_mse: 0.7838
# Epoch 31/49
# 92/92 [==============================] - 77s 836ms/step - loss: 1.0868 - mse: 1.0868 - val_loss: 0.7839 - val_mse: 0.7839
# Epoch 32/49
# 92/92 [==============================] - 76s 821ms/step - loss: 1.0874 - mse: 1.0874 - val_loss: 0.7839 - val_mse: 0.7839
# Epoch 33/49
# 92/92 [==============================] - 79s 862ms/step - loss: 1.0866 - mse: 1.0866 - val_loss: 0.7835 - val_mse: 0.7835
# Epoch 34/49
# 92/92 [==============================] - 80s 867ms/step - loss: 1.0867 - mse: 1.0867 - val_loss: 0.7838 - val_mse: 0.7838
# Epoch 35/49
# 92/92 [==============================] - 84s 912ms/step - loss: 1.0866 - mse: 1.0866 - val_loss: 0.7838 - val_mse: 0.7838
# Epoch 36/49
# 92/92 [==============================] - 84s 913ms/step - loss: 1.0873 - mse: 1.0873 - val_loss: 0.7837 - val_mse: 0.7837
# Epoch 37/49
# 92/92 [==============================] - 79s 858ms/step - loss: 1.0862 - mse: 1.0862 - val_loss: 0.7839 - val_mse: 0.7839
# Epoch 38/49
# 92/92 [==============================] - 76s 827ms/step - loss: 1.0869 - mse: 1.0869 - val_loss: 0.7839 - val_mse: 0.7839
# Epoch 39/49
# 92/92 [==============================] - 74s 803ms/step - loss: 1.0863 - mse: 1.0863 - val_loss: 0.7839 - val_mse: 0.7839
# Epoch 40/49
# 92/92 [==============================] - 73s 794ms/step - loss: 1.0855 - mse: 1.0855 - val_loss: 0.7840 - val_mse: 0.7840
# Epoch 41/49
# 92/92 [==============================] - 73s 797ms/step - loss: 1.0861 - mse: 1.0861 - val_loss: 0.7843 - val_mse: 0.7843
# Epoch 42/49
# 92/92 [==============================] - 79s 859ms/step - loss: 1.0854 - mse: 1.0854 - val_loss: 0.7844 - val_mse: 0.7844
# Epoch 43/49
# 92/92 [==============================] - 74s 804ms/step - loss: 1.0861 - mse: 1.0861 - val_loss: 0.7846 - val_mse: 0.7846
# Epoch 44/49
# 92/92 [==============================] - 76s 828ms/step - loss: 1.0860 - mse: 1.0860 - val_loss: 0.7848 - val_mse: 0.7848
# Epoch 45/49
# 92/92 [==============================] - 79s 854ms/step - loss: 1.0879 - mse: 1.0879 - val_loss: 0.7848 - val_mse: 0.7848
# Epoch 46/49
# 92/92 [==============================] - 31s 341ms/step - loss: 1.0862 - mse: 1.0862 - val_loss: 0.7849 - val_mse: 0.7849

# %%
train_pred = model_1.predict(x_train)
test_pred = model_1.predict(x_test)
# Out:
# 29/29 [==============================] - 14s 265ms/step
# 6/6 [==============================] - 2s 255ms/step

# %%
train_pred.shape
# Out:
# (917, 1)

# %%
y_train.shape, train_pred.shape
# Out:
# ((917,), (917, 1))

# %% [markdown]
# # Accuracy of Model

# %%
rmse = np.sqrt(mean_squared_error(y_true = y_train, y_pred = train_pred))
print("RMSE: {:.2f}".format(rmse))
# Out:
# RMSE: 1.04

# %%
rmse = np.sqrt(mean_squared_error(y_true = y_test, y_pred = test_pred))
print("RMSE: {:.2f}".format(rmse))
# Out:
# RMSE: 0.78

# %%
train_pred = scaler.inverse_transform(train_pred)
test_pred = scaler.inverse_transform(test_pred)
train_pred.shape, test_pred.shape
# Out:
# ((917, 1), (192, 1))

# %%
df3.shape
# Out:
# (1211, 1)

# %%
import numpy
### Plotting 
# shift train predictions for plotting
look_back = 50
trainPredictPlot = numpy.empty_like(df3)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_pred)+look_back, :] = train_pred

# %%
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df3)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_pred)+(look_back*2)+1:len(df3)-1, :] = test_pred

# %%
testPredictPlot
# Out:
# array([[       nan],
#        [       nan],
#        [       nan],
#        ...,
#        [0.00040941],
#        [0.00040941],
#        [       nan]])

# %%
df3 = scaler.inverse_transform(df3)

# %% [markdown]
# # Visualization of Results

# %%
# plot baseline and predictions
plt.figure(figsize = (18,10))
plt.plot((df3),label = "Original Dataset ")
plt.plot((trainPredictPlot),label= "Prediction X_train ")
plt.plot((testPredictPlot),label = "Prediction X_test ")
plt.xlabel('Dateset', fontsize=18)
plt.ylabel('Return USD ($)', fontsize=18)
plt.legend()
plt.show()

# %%
len(train_data),len(test_data)
# Out:
# (968, 243)

# %%
time_stamp = 50
var = len(test_data)-time_stamp
x_input = test_data[var:].reshape(1,-1)
x_input.shape
# Out:
# (1, 50)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 1 days
from numpy import array

lst_output=[]
n_steps=50
i=0
while(i<1):
    
    if(len(temp_input)>n_steps):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        #print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model_1.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model_1.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.]
# 51

# %%
lst_output = scaler.inverse_transform(lst_output)

# %%
day_new=np.arange(1,51)
day_pred=np.arange(51,52)

# %%
import matplotlib.pyplot as plt

# %%
len(df3)
# Out:
# 1211

# %% [markdown]
# # Ploting Predicted Value

# %%
var_1 = len(df3)-time_stamp
plt.figure(figsize = (20,10))
plt.plot(day_new,(df3[var_1:]))
plt.scatter(day_pred,(lst_output), c = "r")
plt.xlabel('Dateset', fontsize=18)
plt.ylabel('Return USD ($)', fontsize=18)
# Out:
# Text(0, 0.5, 'Return USD ($)')

# %%
plt.figure(figsize = (20,10))
df3 = df3.tolist()
df3.extend((lst_output))
plt.plot((df3[var_1:]))
plt.xlabel('Dateset', fontsize=18)
plt.ylabel('Return USD ($)', fontsize=18)
# Out:
# Text(0, 0.5, 'Return USD ($)')

# %% [markdown]
# # Loading New Data for Cross Checking

# %%
check_df = yf.download('^NSEI',start="2022-12-01", end="2023-01-04",interval='1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
check_df["Close"].tail(10)
# Out:
# Date
# 2022-12-21 00:00:00+05:30    18199.099609
# 2022-12-22 00:00:00+05:30    18127.349609
# 2022-12-23 00:00:00+05:30    17806.800781
# 2022-12-26 00:00:00+05:30    18014.599609
# 2022-12-27 00:00:00+05:30    18132.300781
# 2022-12-28 00:00:00+05:30    18122.500000
# 2022-12-29 00:00:00+05:30    18191.000000
# 2022-12-30 00:00:00+05:30    18105.300781
# 2023-01-02 00:00:00+05:30    18197.449219
# 2023-01-03 00:00:00+05:30    18232.550781
# Name: Close, dtype: float64

# %%
check_df["Return"] = check_df.Close.pct_change()

# %%
check_df1 = check_df["Return"].dropna()
check_df1,df1[1425:]
# Out:
# (Date
#  2022-12-02 00:00:00+05:30   -0.006187
#  2022-12-05 00:00:00+05:30    0.000265
#  2022-12-06 00:00:00+05:30   -0.003118
#  2022-12-07 00:00:00+05:30   -0.004412
#  2022-12-08 00:00:00+05:30    0.002632
#  2022-12-09 00:00:00+05:30   -0.006059
#  2022-12-12 00:00:00+05:30    0.000030
#  2022-12-13 00:00:00+05:30    0.005993
#  2022-12-14 00:00:00+05:30    0.002811
#  2022-12-15 00:00:00+05:30   -0.013151
#  2022-12-16 00:00:00+05:30   -0.007923
#  2022-12-19 00:00:00+05:30    0.008290
#  2022-12-20 00:00:00+05:30   -0.001908
#  2022-12-21 00:00:00+05:30   -0.010128
#  2022-12-22 00:00:00+05:30   -0.003943
#  2022-12-23 00:00:00+05:30   -0.017683
#  2022-12-26 00:00:00+05:30    0.011670
#  2022-12-27 00:00:00+05:30    0.006534
#  2022-12-28 00:00:00+05:30   -0.000541
#  2022-12-29 00:00:00+05:30    0.003780
#  2022-12-30 00:00:00+05:30   -0.004711
#  2023-01-02 00:00:00+05:30    0.005090
#  2023-01-03 00:00:00+05:30    0.001929
#  Name: Return, dtype: float64,
#  Empty DataFrame
#  Columns: [Close, Return, Log_Return]
#  Index: [])

# %%
for_adding_date = yf.download('^NSEI',start="2018-01-31", end="2022-12-31",interval='1d')
for_adding_date.shape
for_adding_date.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    Open          High           Low  \
# Date
# 2022-12-26 00:00:00+05:30  17830.400391  18084.099609  17774.250000
# 2022-12-27 00:00:00+05:30  18089.800781  18149.250000  17967.449219
# 2022-12-28 00:00:00+05:30  18084.750000  18173.099609  18068.349609
# 2022-12-29 00:00:00+05:30  18045.699219  18229.699219  17992.800781
# 2022-12-30 00:00:00+05:30  18259.099609  18265.250000  18080.300781
#
#                                   Close     Adj Close  Volume
# Date
# 2022-12-26 00:00:00+05:30  18014.599609  18014.599609  176700
# 2022-12-27 00:00:00+05:30  18132.300781  18132.300781  214300
# 2022-12-28 00:00:00+05:30  18122.500000  18122.500000  193900
# 2022-12-29 00:00:00+05:30  18191.000000  18191.000000  281100
# 2022-12-30 00:00:00+05:30  18105.300781  18105.300781  192000

# %%
df4 = pd.DataFrame(df3)

# %%
df4 = df4.set_index(for_adding_date.index)

# %%
# Ploting Final comparision 
plt.figure(figsize = (20,10))
plt.subplot(3,1,1)
plt.plot(check_df1,label = "New Data")
plt.ylabel('Return USD ($)', fontsize=18)
plt.legend()
plt.subplot(3,1,2)
plt.plot(df2[var_1+30:], label = "Original Data", color = "r")
plt.ylabel('Return USD ($)', fontsize=18)
plt.legend()
plt.subplot(3,1,3)
plt.plot(df4[var_1+30:], label = "Predicted Data", c = "g")
plt.xlabel('Dateset', fontsize=18)
plt.ylabel('Return USD ($)', fontsize=18)
plt.legend()
