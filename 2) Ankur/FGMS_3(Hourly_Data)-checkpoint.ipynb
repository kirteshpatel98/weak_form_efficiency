# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller, acf, pacf
import yfinance as yf

# %%
sp500 = yf.download('^GSPC',start="2022-09-01", end="2022-09-30",interval='60m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
sp500.head()
# Out:
#                                   Open         High          Low        Close  \
# Datetime
# 2022-09-01 09:30:00-04:00  3936.729980  3936.729980  3908.419922  3928.550049
# 2022-09-01 10:30:00-04:00  3928.659912  3928.870117  3903.649902  3911.270020
# 2022-09-01 11:30:00-04:00  3911.260010  3928.070068  3909.820068  3920.250000
# 2022-09-01 12:30:00-04:00  3920.199951  3933.260010  3906.060059  3932.409912
# 2022-09-01 13:30:00-04:00  3932.500000  3946.899902  3921.739990  3944.429932
#
#                              Adj Close     Volume
# Datetime
# 2022-09-01 09:30:00-04:00  3928.550049          0
# 2022-09-01 10:30:00-04:00  3911.270020  326278527
# 2022-09-01 11:30:00-04:00  3920.250000  234777199
# 2022-09-01 12:30:00-04:00  3932.409912  212320000
# 2022-09-01 13:30:00-04:00  3944.429932  205485000

# %%
# Clean the data and convert to daily returns
sp500["returns"] = np.log(sp500["Close"]/sp500["Close"].shift(1))
sp500 = sp500.dropna()

# %%
# Calculate the moving average of the stock prices
window_size = 50
sp500["ma"] = sp500["Close"].rolling(window=window_size).mean()

# Plot the moving average and the stock prices
plt.figure(figsize=(12, 8))
plt.plot(sp500["Close"], label="Stock Prices")
plt.plot(sp500["ma"], label="Moving Average")
plt.xlabel("Year")
plt.ylabel("Price")
plt.title("S&P 500 Moving Average")
plt.legend()
plt.show()
# Out:
# C:\Users\agarw\AppData\Local\Temp\ipykernel_24160\827370201.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500["ma"] = sp500["Close"].rolling(window=window_size).mean()

# %%
# Calculate EWMA
sp500["EWMA"] = sp500["Close"].ewm(span=30, adjust=False).mean()

# Plot the original closing prices and the EWMA
plt.figure(figsize=(15, 8))
plt.plot(sp500["Close"], label="Closing Prices")
plt.plot(sp500["EWMA"], label="EWMA")
plt.plot(sp500["ma"], label="Moving Average")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Price")
plt.title("S&P 500 Closing Prices and EWMA")
plt.show()
# Out:
# C:\Users\agarw\AppData\Local\Temp\ipykernel_24160\3961490358.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500["EWMA"] = sp500["Close"].ewm(span=30, adjust=False).mean()

# %%
result = adfuller(sp500["Close"])
print("Augmented Dickey-Fuller Test Results")
print("Test Statistic: {:.3f}".format(result[0]))
print("p-value: {:.3f}".format(result[1]))
print("Critical Values:")
for key, value in result[4].items():
    print("\t{}: {:.3f}".format(key, value))
    
if result[1] < 0.05:
    print("The time series is stationary.")
else:
    print("The time series is not stationary.")
# Out:
# Augmented Dickey-Fuller Test Results
# Test Statistic: -0.272
# p-value: 0.929
# Critical Values:
# 	1%: -3.479
# 	5%: -2.883
# 	10%: -2.578
# The time series is not stationary.

# %% [markdown]
# # Deep Learning

# %%
df = sp500.reset_index()["Close"]
df
# Out:
# 0      3911.270020
# 1      3920.250000
# 2      3932.409912
# 3      3944.429932
# 4      3943.489990
#           ...
# 134    3641.409912
# 135    3630.790039
# 136    3620.229980
# 137    3625.929932
# 138    3641.709961
# Name: Close, Length: 139, dtype: float64

# %%
plt.plot(df)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))
df = scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
df
# Out:
# array([[0.5871413 ],
#        [0.60525743],
#        [0.62978872],
#        [0.65403778],
#        [0.65214156],
#        [0.70003438],
#        [0.7783698 ],
#        [0.78978805],
#        [0.74280295],
#        [0.64015838],
#        [0.64280128],
#        [0.62311153],
#        [0.61542515],
#        [0.57606585],
#        [0.6119553 ],
#        [0.59220497],
#        [0.55996712],
#        [0.59085348],
#        [0.5884928 ],
#        [0.58490179],
#        [0.61578815],
#        [0.64822794],
#        [0.63923046],
#        [0.66347953],
#        [0.71300606],
#        [0.7409673 ],
#        [0.72583688],
#        [0.72678499],
#        [0.77677598],
#        [0.69327592],
#        [0.75367696],
#        [0.75648092],
#        [0.75325339],
#        [0.77796642],
#        [0.87344916],
#        [0.8815793 ],
#        [0.8673566 ],
#        [0.89725446],
#        [0.90877368],
#        [0.91339358],
#        [0.90256045],
#        [1.        ],
#        [0.99245547],
#        [0.96386823],
#        [0.99142609],
#        [0.96927519],
#        [0.97478262],
#        [0.98991305],
#        [0.77314458],
#        [0.73007359],
#        [0.73120296],
#        [0.75855889],
#        [0.71407533],
#        [0.65286803],
#        [0.63035364],
#        [0.60664931],
#        [0.65774996],
#        [0.65315025],
#        [0.66660609],
#        [0.62845742],
#        [0.60687144],
#        [0.65819373],
#        [0.62313172],
#        [0.6093326 ],
#        [0.57701397],
#        [0.64693653],
#        [0.60955423],
#        [0.54590597],
#        [0.56735059],
#        [0.47886813],
#        [0.46527094],
#        [0.44142525],
#        [0.45354979],
#        [0.48088552],
#        [0.49266677],
#        [0.50904821],
#        [0.50902802],
#        [0.49910212],
#        [0.48609006],
#        [0.51582637],
#        [0.49863816],
#        [0.55456065],
#        [0.56488943],
#        [0.47253325],
#        [0.48635257],
#        [0.4872603 ],
#        [0.44731588],
#        [0.44890969],
#        [0.47789983],
#        [0.47717335],
#        [0.53850181],
#        [0.51191275],
#        [0.5243195 ],
#        [0.51395033],
#        [0.4316811 ],
#        [0.42724294],
#        [0.34214956],
#        [0.30361722],
#        [0.27708873],
#        [0.29278409],
#        [0.29016138],
#        [0.27603965],
#        [0.31283683],
#        [0.27573675],
#        [0.16169362],
#        [0.1439006 ],
#        [0.0909643 ],
#        [0.10490429],
#        [0.08475058],
#        [0.11376091],
#        [0.15130426],
#        [0.18759709],
#        [0.10893907],
#        [0.08208749],
#        [0.06120779],
#        [0.06606953],
#        [0.09754101],
#        [0.07242411],
#        [0.12578447],
#        [0.0913071 ],
#        [0.03145129],
#        [0.02620588],
#        [0.03068443],
#        [0.04809476],
#        [0.05701147],
#        [0.1121267 ],
#        [0.13375306],
#        [0.15598474],
#        [0.17359652],
#        [0.16544619],
#        [0.20563244],
#        [0.19661476],
#        [0.02194946],
#        [0.03990404],
#        [0.04272819],
#        [0.02130376],
#        [0.        ],
#        [0.01149903],
#        [0.0433335 ]])

# %%
train_size = int(len(df)*0.65)
test_size = len(df) - train_size
train_data,test_data=df[0:train_size,:],df[train_size:len(df),:1]

# %%
train_size,test_size
# Out:
# (90, 49)

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
import numpy
time_step = 4
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (85, 4)
# (85,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (44, 4)
# (44,)
# (None, None)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50, return_sequences = True, input_shape = (4,1)))
model.add(LSTM(50, return_sequences = True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss = "mean_squared_error", optimizer = "adam")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 4, 50)             10400
#
#  lstm_1 (LSTM)               (None, 4, 50)             20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 5s 907ms/step - loss: 0.4601 - val_loss: 0.0271
# Epoch 2/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4177 - val_loss: 0.0213
# Epoch 3/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3751 - val_loss: 0.0161
# Epoch 4/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3288 - val_loss: 0.0118
# Epoch 5/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2777 - val_loss: 0.0093
# Epoch 6/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2210 - val_loss: 0.0102
# Epoch 7/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1595 - val_loss: 0.0170
# Epoch 8/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0972 - val_loss: 0.0342
# Epoch 9/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0422 - val_loss: 0.0680
# Epoch 10/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0100 - val_loss: 0.1213
# Epoch 11/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0217 - val_loss: 0.1690
# Epoch 12/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0537 - val_loss: 0.1737
# Epoch 13/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0515 - val_loss: 0.1473
# Epoch 14/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0284 - val_loss: 0.1154
# Epoch 15/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0124 - val_loss: 0.0898
# Epoch 16/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0092 - val_loss: 0.0729
# Epoch 17/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0139 - val_loss: 0.0636
# Epoch 18/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0185 - val_loss: 0.0605
# Epoch 19/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0205 - val_loss: 0.0618
# Epoch 20/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0191 - val_loss: 0.0670
# Epoch 21/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0156 - val_loss: 0.0757
# Epoch 22/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0122 - val_loss: 0.0865
# Epoch 23/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0096 - val_loss: 0.0971
# Epoch 24/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0094 - val_loss: 0.1058
# Epoch 25/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0107 - val_loss: 0.1106
# Epoch 26/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0118 - val_loss: 0.1104
# Epoch 27/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0117 - val_loss: 0.1062
# Epoch 28/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0107 - val_loss: 0.0996
# Epoch 29/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0095 - val_loss: 0.0923
# Epoch 30/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0090 - val_loss: 0.0857
# Epoch 31/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0093 - val_loss: 0.0812
# Epoch 32/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0095 - val_loss: 0.0796
# Epoch 33/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0095 - val_loss: 0.0798
# Epoch 34/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0092 - val_loss: 0.0810
# Epoch 35/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0089 - val_loss: 0.0829
# Epoch 36/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0086 - val_loss: 0.0847
# Epoch 37/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0086 - val_loss: 0.0860
# Epoch 38/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0086 - val_loss: 0.0858
# Epoch 39/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0086 - val_loss: 0.0843
# Epoch 40/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0085 - val_loss: 0.0826
# Epoch 41/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0083 - val_loss: 0.0814
# Epoch 42/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0083 - val_loss: 0.0800
# Epoch 43/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0081 - val_loss: 0.0776
# Epoch 44/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0080 - val_loss: 0.0749
# Epoch 45/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0080 - val_loss: 0.0730
# Epoch 46/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0080 - val_loss: 0.0719
# Epoch 47/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0079 - val_loss: 0.0710
# Epoch 48/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0078 - val_loss: 0.0711
# Epoch 49/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0076 - val_loss: 0.0719
# Epoch 50/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0076 - val_loss: 0.0725
# Epoch 51/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0077 - val_loss: 0.0719
# Epoch 52/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0076 - val_loss: 0.0697
# Epoch 53/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0074 - val_loss: 0.0676
# Epoch 54/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0073 - val_loss: 0.0654
# Epoch 55/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0072 - val_loss: 0.0643
# Epoch 56/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0071 - val_loss: 0.0633
# Epoch 57/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0070 - val_loss: 0.0622
# Epoch 58/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0070 - val_loss: 0.0613
# Epoch 59/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0069 - val_loss: 0.0608
# Epoch 60/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0068 - val_loss: 0.0603
# Epoch 61/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0068 - val_loss: 0.0598
# Epoch 62/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0067 - val_loss: 0.0583
# Epoch 63/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0066 - val_loss: 0.0565
# Epoch 64/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0065 - val_loss: 0.0546
# Epoch 65/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0065 - val_loss: 0.0535
# Epoch 66/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0064 - val_loss: 0.0532
# Epoch 67/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0063 - val_loss: 0.0527
# Epoch 68/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0063 - val_loss: 0.0523
# Epoch 69/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0063 - val_loss: 0.0516
# Epoch 70/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0063 - val_loss: 0.0501
# Epoch 71/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0061 - val_loss: 0.0478
# Epoch 72/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0060 - val_loss: 0.0459
# Epoch 73/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0060 - val_loss: 0.0445
# Epoch 74/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0059 - val_loss: 0.0431
# Epoch 75/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0059 - val_loss: 0.0424
# Epoch 76/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0059 - val_loss: 0.0424
# Epoch 77/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0058 - val_loss: 0.0423
# Epoch 78/100
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0057 - val_loss: 0.0422
# Epoch 79/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0057 - val_loss: 0.0419
# Epoch 80/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0057 - val_loss: 0.0410
# Epoch 81/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0056 - val_loss: 0.0391
# Epoch 82/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.0056 - val_loss: 0.0371
# Epoch 83/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0056 - val_loss: 0.0364
# Epoch 84/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0055 - val_loss: 0.0368
# Epoch 85/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0055 - val_loss: 0.0373
# Epoch 86/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0055 - val_loss: 0.0371
# Epoch 87/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0055 - val_loss: 0.0368
# Epoch 88/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0055 - val_loss: 0.0363
# Epoch 89/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0055 - val_loss: 0.0355
# Epoch 90/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0054 - val_loss: 0.0338
# Epoch 91/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0053 - val_loss: 0.0324
# Epoch 92/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0053 - val_loss: 0.0316
# Epoch 93/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0054 - val_loss: 0.0312
# Epoch 94/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0053 - val_loss: 0.0314
# Epoch 95/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0053 - val_loss: 0.0314
# Epoch 96/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0053 - val_loss: 0.0312
# Epoch 97/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0053 - val_loss: 0.0309
# Epoch 98/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0053 - val_loss: 0.0303
# Epoch 99/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0052 - val_loss: 0.0294
# Epoch 100/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0053 - val_loss: 0.0288

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 3/3 [==============================] - 1s 2ms/step
# 2/2 [==============================] - 0s 2ms/step

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 3948.998820370366

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 3771.5837194450405

# %%
### Plotting 
# shift train predictions for plotting
plt.figure(figsize=(12, 8))
look_back=4
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 49

# %%
x_input=test_data[45:].reshape(1,-1)
x_input.shape
# Out:
# (1, 4)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=4
i=0
while(i<4):
    
    if(len(temp_input)>4):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [0.20376806]
# 5
# 1 day input [0.         0.01149903 0.0433335  0.20376806]
# 1 day output [[0.20923221]]
# 2 day input [0.01149903 0.0433335  0.20376806 0.20923221]
# 2 day output [[0.23354644]]
# 3 day input [0.0433335  0.20376806 0.20923221 0.23354644]
# 3 day output [[0.27220887]]
# [[0.2037680596113205], [0.20923221111297607], [0.2335464358329773], [0.2722088694572449]]

# %%
day_new=np.arange(1,5)
day_pred=np.arange(5,9)

# %%
import matplotlib.pyplot as plt

# %%
len(df)
# Out:
# 139

# %%
plt.plot(day_new,scaler.inverse_transform(df[135:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
sp_pred = yf.download('^GSPC',start="2022-09-29", end="2022-10-01",interval='1h')
sp_pred
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                   Open         High          Low        Close  \
# Datetime
# 2022-09-29 09:30:00-04:00  3687.010010  3687.010010  3619.689941  3631.110107
# 2022-09-29 10:30:00-04:00  3631.129883  3651.409912  3621.139893  3640.010010
# 2022-09-29 11:30:00-04:00  3640.110107  3659.070068  3636.729980  3641.409912
# 2022-09-29 12:30:00-04:00  3641.409912  3646.860107  3628.229980  3630.790039
# 2022-09-29 13:30:00-04:00  3630.760010  3636.929932  3610.399902  3620.229980
# 2022-09-29 14:30:00-04:00  3620.209961  3632.280029  3612.260010  3625.929932
# 2022-09-29 15:30:00-04:00  3625.929932  3645.250000  3624.909912  3641.709961
# 2022-09-30 09:30:00-04:00  3633.479980  3648.919922  3614.540039  3643.500000
# 2022-09-30 10:30:00-04:00  3643.489990  3671.439941  3642.550049  3666.409912
# 2022-09-30 11:30:00-04:00  3666.429932  3668.810059  3631.530029  3637.530029
# 2022-09-30 12:30:00-04:00  3637.520020  3646.360107  3633.780029  3640.000000
# 2022-09-30 13:30:00-04:00  3640.020020  3641.330078  3616.949951  3620.100098
# 2022-09-30 14:30:00-04:00  3620.110107  3624.800049  3601.949951  3612.719971
# 2022-09-30 15:30:00-04:00  3612.949951  3619.050049  3584.129883  3589.290039
#
#                              Adj Close     Volume
# Datetime
# 2022-09-29 09:30:00-04:00  3631.110107          0
# 2022-09-29 10:30:00-04:00  3640.010010  321149770
# 2022-09-29 11:30:00-04:00  3641.409912  254439461
# 2022-09-29 12:30:00-04:00  3630.790039  211138000
# 2022-09-29 13:30:00-04:00  3620.229980  268888000
# 2022-09-29 14:30:00-04:00  3625.929932  315881000
# 2022-09-29 15:30:00-04:00  3641.709961  414350000
# 2022-09-30 09:30:00-04:00  3643.500000          0
# 2022-09-30 10:30:00-04:00  3666.409912  366711622
# 2022-09-30 11:30:00-04:00  3637.530029  269345947
# 2022-09-30 12:30:00-04:00  3640.000000  206343000
# 2022-09-30 13:30:00-04:00  3620.100098  243797000
# 2022-09-30 14:30:00-04:00  3612.719971  318260000
# 2022-09-30 15:30:00-04:00  3589.290039  516242000

# %%
df1 = sp_pred.reset_index()["Close"]

# %%
plt.figure(figsize = (15,6))
plt.plot(df1)

# %% [markdown]
# # Arima Model

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
result = adf_test(sp500['Close'].dropna())
# Out:
# ADF Statistics: -0.7200755796927667
# p- value: 0.8414807584155444
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
### First Shift 
## Use Techniques Differencing
sp500['Close_1']=sp500["Close"]-sp500["Close"].shift(1)
# Out:
# C:\Users\agarw\AppData\Local\Temp\ipykernel_22372\2897223724.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500['Close_1']=sp500["Close"]-sp500["Close"].shift(1)

# %%
result = adf_test(sp500['Close_1'].dropna())
# Out:
# ADF Statistics: -15.455432751226276
# p- value: 2.7492596733930657e-28
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
fig = plt.figure(figsize=(12,12))
ax1 = fig.add_subplot(211)
acf = sm.graphics.tsa.plot_acf(sp500['Close_1'].dropna(),lags=50, ax=ax1)
ax2 = fig.add_subplot(212)
pacf = sm.graphics.tsa.plot_pacf(sp500['Close_1'].dropna(),lags=50, ax=ax2)
# Out:
# C:\Users\agarw\Anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# For non-seasonal data
#p=0, d=1, q=0 or 1
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# %%
model = sm.tsa.arima.ARIMA(sp500["Close"],order=(45,1,45))
model_fit=model.fit()
# Out:
# C:\Users\agarw\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\agarw\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\agarw\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\agarw\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\agarw\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\agarw\Anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  250
# Model:               ARIMA(45, 1, 45)   Log Likelihood               -1343.599
# Date:                Wed, 08 Feb 2023   AIC                           2869.198
# Time:                        13:13:40   BIC                           3189.286
# Sample:                             0   HQIC                          2998.039
#                                 - 250
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0744      0.715     -0.104      0.917      -1.475       1.326
# ar.L2         -0.1783      0.561     -0.318      0.751      -1.278       0.921
# ar.L3         -0.0242      0.612     -0.039      0.969      -1.224       1.175
# ar.L4          0.2128      0.445      0.478      0.633      -0.660       1.086
# ar.L5          0.0715      0.345      0.207      0.836      -0.605       0.748
# ar.L6          0.3206      0.310      1.036      0.300      -0.286       0.927
# ar.L7          0.3485      0.205      1.700      0.089      -0.053       0.750
# ar.L8         -0.0166      0.343     -0.048      0.961      -0.689       0.656
# ar.L9          0.1519      0.252      0.602      0.547      -0.343       0.647
# ar.L10        -0.1155      0.356     -0.324      0.746      -0.814       0.583
# ar.L11         0.0645      0.261      0.247      0.805      -0.447       0.576
# ar.L12         0.0199      0.309      0.064      0.949      -0.585       0.625
# ar.L13        -0.3795      0.304     -1.248      0.212      -0.975       0.216
# ar.L14        -0.1481      0.254     -0.583      0.560      -0.646       0.350
# ar.L15        -0.1320      0.320     -0.413      0.680      -0.759       0.495
# ar.L16         0.0143      0.313      0.046      0.964      -0.600       0.628
# ar.L17         0.3701      0.270      1.370      0.171      -0.160       0.900
# ar.L18         0.1523      0.222      0.686      0.493      -0.283       0.588
# ar.L19         0.3639      0.290      1.254      0.210      -0.205       0.932
# ar.L20         0.4143      0.420      0.987      0.323      -0.408       1.237
# ar.L21         0.4116      0.569      0.724      0.469      -0.703       1.526
# ar.L22        -0.1230      0.738     -0.167      0.868      -1.569       1.323
# ar.L23        -0.0782      0.510     -0.153      0.878      -1.078       0.922
# ar.L24        -0.2134      0.434     -0.492      0.623      -1.063       0.637
# ar.L25        -0.3425      0.284     -1.206      0.228      -0.899       0.214
# ar.L26         0.0022      0.233      0.010      0.992      -0.455       0.459
# ar.L27         0.0762      0.197      0.388      0.698      -0.309       0.462
# ar.L28        -0.3007      0.225     -1.335      0.182      -0.742       0.141
# ar.L29         0.2685      0.331      0.811      0.418      -0.381       0.918
# ar.L30         0.0351      0.311      0.113      0.910      -0.575       0.646
# ar.L31         0.1393      0.245      0.568      0.570      -0.341       0.620
# ar.L32         0.2543      0.252      1.010      0.312      -0.239       0.748
# ar.L33         0.0399      0.361      0.111      0.912      -0.667       0.747
# ar.L34         0.2613      0.331      0.790      0.429      -0.387       0.909
# ar.L35        -0.1389      0.490     -0.284      0.777      -1.099       0.821
# ar.L36        -0.1446      0.308     -0.470      0.638      -0.748       0.459
# ar.L37        -0.1651      0.181     -0.914      0.361      -0.519       0.189
# ar.L38        -0.3008      0.175     -1.721      0.085      -0.643       0.042
# ar.L39        -0.2722      0.280     -0.971      0.332      -0.822       0.277
# ar.L40        -0.0700      0.432     -0.162      0.871      -0.917       0.777
# ar.L41        -0.3001      0.359     -0.835      0.403      -1.004       0.404
# ar.L42         0.0630      0.489      0.129      0.897      -0.895       1.021
# ar.L43        -0.0779      0.383     -0.203      0.839      -0.828       0.673
# ar.L44         0.0381      0.401      0.095      0.924      -0.748       0.824
# ar.L45         0.4263      0.325      1.313      0.189      -0.210       1.062
# ma.L1          0.1299     60.671      0.002      0.998    -118.784     119.044
# ma.L2          0.1548     65.299      0.002      0.998    -127.829     128.138
# ma.L3          0.0994     42.613      0.002      0.998     -83.421      83.620
# ma.L4         -0.1127     64.381     -0.002      0.999    -126.298     126.073
# ma.L5          0.0030     84.669   3.53e-05      1.000    -165.946     165.952
# ma.L6         -0.2664     39.199     -0.007      0.995     -77.095      76.562
# ma.L7         -0.2853     53.627     -0.005      0.996    -105.393     104.823
# ma.L8         -0.1943     45.705     -0.004      0.997     -89.774      89.386
# ma.L9         -0.2386     84.664     -0.003      0.998    -166.177     165.700
# ma.L10        -0.2290     52.621     -0.004      0.997    -103.364     102.906
# ma.L11        -0.0436     74.760     -0.001      1.000    -146.571     146.484
# ma.L12        -0.0852     51.021     -0.002      0.999    -100.085      99.914
# ma.L13         0.4596     38.119      0.012      0.990     -74.253      75.172
# ma.L14         0.3338     82.043      0.004      0.997    -160.467     161.134
# ma.L15         0.1600     87.317      0.002      0.999    -170.979     171.299
# ma.L16         0.2217     68.260      0.003      0.997    -133.566     134.010
# ma.L17        -0.3494     61.525     -0.006      0.995    -120.937     120.238
# ma.L18        -0.2444     65.745     -0.004      0.997    -129.102     128.614
# ma.L19        -0.3241     45.360     -0.007      0.994     -89.228      88.580
# ma.L20        -0.5467     77.644     -0.007      0.994    -152.726     151.632
# ma.L21        -0.5791     67.614     -0.009      0.993    -133.100     131.941
# ma.L22        -0.0782     57.113     -0.001      0.999    -112.018     111.861
# ma.L23        -0.1664     70.249     -0.002      0.998    -137.852     137.519
# ma.L24         0.1890     82.103      0.002      0.998    -160.730     161.108
# ma.L25         0.3604     89.218      0.004      0.997    -174.504     175.224
# ma.L26         0.2278     42.865      0.005      0.996     -83.786      84.242
# ma.L27         0.0423     59.705      0.001      0.999    -116.977     117.062
# ma.L28         0.4268     57.238      0.007      0.994    -111.759     112.612
# ma.L29        -0.0303     55.403     -0.001      1.000    -108.619     108.558
# ma.L30        -0.0848     89.359     -0.001      0.999    -175.226     175.057
# ma.L31        -0.2281     73.678     -0.003      0.998    -144.635     144.179
# ma.L32        -0.5392     45.116     -0.012      0.990     -88.965      87.887
# ma.L33        -0.1588     52.129     -0.003      0.998    -102.329     102.012
# ma.L34        -0.2022     70.434     -0.003      0.998    -138.250     137.846
# ma.L35         0.0235     49.115      0.000      1.000     -96.239      96.286
# ma.L36         0.1777     81.580      0.002      0.998    -159.716     160.071
# ma.L37         0.1458     32.875      0.004      0.996     -64.288      64.580
# ma.L38         0.3359     60.741      0.006      0.996    -118.715     119.386
# ma.L39         0.4772     37.685      0.013      0.990     -73.383      74.338
# ma.L40         0.0704     69.075      0.001      0.999    -135.314     135.455
# ma.L41         0.2420     56.662      0.004      0.997    -110.814     111.298
# ma.L42         0.2696     31.792      0.008      0.993     -62.041      62.580
# ma.L43         0.0788     54.345      0.001      0.999    -106.435     106.593
# ma.L44         0.1789     42.844      0.004      0.997     -83.794      84.152
# ma.L45        -0.7070      0.694     -1.018      0.309      -2.068       0.654
# sigma2      1157.9890      0.468   2475.477      0.000    1157.072    1158.906
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 7.25
# Prob(Q):                              0.88   Prob(JB):                         0.03
# Heteroskedasticity (H):               1.38   Skew:                            -0.42
# Prob(H) (two-sided):                  0.15   Kurtosis:                         3.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.76e+21. Standard errors may be unstable.
# """

# %%
sp500['forecast']=model_fit.predict(start="2022-05-01",end="2022-05-28",dynamic=True)
sp500[['Close','forecast']].plot(figsize=(12,8))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:545, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1651377600000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:513, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:547, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2022-05-01 00:00:00-0400', tz='America/New_York')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:679, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     678 try:
# --> 679     return Index.get_loc(self, key, method, tolerance)
#     680 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#
# KeyError: Timestamp('2022-05-01 00:00:00-0400', tz='America/New_York')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:247, in get_index_label_loc(key, index, row_labels)
#     246 if not isinstance(key, (int, np.integer)):
# --> 247     loc = row_labels.get_loc(key)
#     248 else:
#
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:681, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     680 except KeyError as err:
# --> 681     raise KeyError(orig_key) from err
#
# KeyError: '2022-05-01'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:356, in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     355 try:
# --> 356     start, _, start_oos = get_index_label_loc(
#     357         start, base_index, data.row_labels
#     358     )
#     359 except KeyError:
#
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:279, in get_index_label_loc(key, index, row_labels)
#     278     except:
# --> 279         raise e
#     280 return loc, index, index_was_expanded
#
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:243, in get_index_label_loc(key, index, row_labels)
#     242 try:
# --> 243     loc, index, index_was_expanded = get_index_loc(key, index)
#     244 except KeyError as e:
#
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:193, in get_index_loc(key, index)
#     192 except (IndexError, ValueError) as e:
# --> 193     raise KeyError(str(e))
#     194 loc = key
#
# KeyError: 'only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 sp500['forecast']=model_fit.predict(start="2022-05-01",end="2022-05-28",dynamic=True)
#       2 sp500[['Close','forecast']].plot(figsize=(12,8))
#
# File ~\Anaconda3\lib\site-packages\statsmodels\base\wrapper.py:113, in make_wrapper.<locals>.wrapper(self, *args, **kwargs)
#     111     obj = data.wrap_output(func(results, *args, **kwargs), how[0], how[1:])
#     112 elif how:
# --> 113     obj = data.wrap_output(func(results, *args, **kwargs), how)
#     114 return obj
#
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:3403, in MLEResults.predict(self, start, end, dynamic, **kwargs)
#    3357 """
#    3358 In-sample prediction and out-of-sample forecasting
#    3359
#    (...)
#    3400     including confidence intervals.
#    3401 """
#    3402 # Perform the prediction
# -> 3403 prediction_results = self.get_prediction(start, end, dynamic, **kwargs)
#    3404 return prediction_results.predicted_mean
#
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:3287, in MLEResults.get_prediction(self, start, end, dynamic, index, exog, extend_model, extend_kwargs, **kwargs)
#    3283     start = 0
#    3285 # Handle start, end, dynamic
#    3286 start, end, out_of_sample, prediction_index = (
# -> 3287     self.model._get_prediction_index(start, end, index))
#    3289 # Handle `dynamic`
#    3290 if isinstance(dynamic, (str, dt.datetime, pd.Timestamp)):
#
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834, in TimeSeriesModel._get_prediction_index(self, start, end, index, silent)
#     778 """
#     779 Get the location of a specific key in an index or model row labels
#     780
#    (...)
#     831 since we have required them to be full indexes, there is no ambiguity).
#     832 """
#     833 nobs = len(self.endog)
# --> 834 return get_prediction_index(
#     835     start,
#     836     end,
#     837     nobs,
#     838     base_index=self._index,
#     839     index=index,
#     840     silent=silent,
#     841     index_none=self._index_none,
#     842     index_generated=self._index_generated,
#     843     data=self.data,
#     844 )
#
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:360, in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     356     start, _, start_oos = get_index_label_loc(
#     357         start, base_index, data.row_labels
#     358     )
#     359 except KeyError:
# --> 360     raise KeyError(
#     361         "The `start` argument could not be matched to a"
#     362         " location related to the index of the data."
#     363     )
#     364 if end is None:
#     365     end = max(start, len(base_index) - 1)
#
# KeyError: 'The `start` argument could not be matched to a location related to the index of the data.'

# %%
### 12 months 
## Use Techniques Differencing
sp500['Close 12 Difference']=sp500["Close"]-sp500["Close"].shift(24)
# Out:
# C:\Users\agarw\AppData\Local\Temp\ipykernel_22372\1939982788.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500['Close 12 Difference']=sp500["Close"]-sp500["Close"].shift(24)

# %% [markdown]
# # Sarimax

# %%
model=sm.tsa.statespace.SARIMAX(sp500["Close"],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
# Out:
# C:\Users\agarw\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\agarw\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
sp500['forecast']=results.predict(start="2020-10-01",end="2020-11-30",dynamic=True)
sp500[['Close','forecast']].plot(figsize=(12,8))
plt.xlim(pd.Timestamp('2020-06-01'), pd.Timestamp('2021-03-01'))
# Out:
# C:\Users\agarw\AppData\Local\Temp\ipykernel_22372\1148846251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500['forecast']=results.predict(start="2020-10-01",end="2020-11-30",dynamic=True)
# (18414.0, 18687.0)

# %%
result = adf_test(sp500['Close 12 Difference'].dropna())

# %%
### 2_12 months 
## Use Techniques Differencing
sp500['Close 2_12 Difference']=sp500["Close 12 Difference"]-sp500["Close 12 Difference"].shift(1)

# %%
result_1 = adf_test(sp500['Close 2_12 Difference'].dropna())

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
acf12 = plot_acf(sp500['Close 12 Difference'].dropna())

# %%
pacf12 = plot_pacf(sp500['Close 2_12 Difference'].dropna())

# %%
## create a SARIMA model
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_SARIMA=SARIMAX(train_data['Thousands of Passengers'],order=(3,0,5),seasonal_order=(0,1,0,365))

# %%
# Test for random walk hypothesis using Augmented Dickey-Fuller test
result = adfuller(sp500["returns"])
print("ADF Test:")
print("Test Statistic: ", result[0])
print("p-value: ", result[1])
print("Critical Values:")
for key, value in result[4].items():
    print("\t", key, ": ", value)

# %%
# Plot autocorrelation and partial autocorrelation
plt.figure(figsize=(12, 8))

plt.subplot(2,1,1)
acf_result = acf(sp500["returns"], nlags=30)
plt.plot(acf_result)
plt.axhline(y=0, linestyle="--", color="gray")
plt.axhline(y=-1.96/np.sqrt(len(sp500["returns"])), linestyle="--", color="gray")
plt.axhline(y=1.96/np.sqrt(len(sp500["returns"])), linestyle="--", color="gray")
plt.title("Autocorrelation")

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2,1,2)
pacf_result = pacf(sp500["returns"], nlags=30, method="ols")
plt.plot(pacf_result)
plt.axhline(y=0, linestyle="--", color="gray")
plt.axhline(y=-1.96/np.sqrt(len(sp500["returns"])), linestyle="--", color="gray")
plt.axhline(y=1.96/np.sqrt(len(sp500["returns"])), linestyle="--", color="gray")
plt.title("Partial Autocorrelation")

# %%
plt.tight_layout()
plt.show()
